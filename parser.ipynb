# %%
import spacy
from spacy.matcher import Matcher

nlp = spacy.load("en_core_web_sm")

def extract_info_based_on_keywords(doc):
    matcher = Matcher(nlp.vocab)

    # patterns to match the keywords followed by one or more proper nouns
    patterns = [
        [{"LOWER": "to"}, {"POS": "PROPN", "OP": "+"}],
        [{"LOWER": "from"}, {"POS": "PROPN", "OP": "+"}],
        [{"LOWER": "through"}, {"POS": "PROPN", "OP": "+"}]
    ]

    # adding patterns to the matcher
    for pattern in patterns:
        matcher.add("KeyPhrases", [pattern])

    info = {}

    # using named entity recognition to find organizations
    for ent in doc.ents:
        if ent.label_ == "ORG":
            info['organization'] = ent.text
            
    # matching patterns for source, destination, and middle hop
    for match_id, start, end in matcher(doc):
        key = doc[start].text.lower()
        value = doc[start + 1:end].text  # capture all tokens after the keyword until the pattern ends

        if key == 'to':
            info['destination'] = value
        elif key == 'from':
            info['source'] = value
        elif key == 'through':
            info['middle_hop'] = value

    return info

# example
query = "For which destinations are multiple egresses available?"

#  processing
doc = nlp(query)

# extraction based on matching 
info = extract_info_based_on_keywords(doc)
print(info)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 4
#       1 import spacy
#       2 from spacy.matcher import Matcher
# ----> 4 nlp = spacy.load("en_core_web_sm")
#       6 def extract_info_based_on_keywords(doc):
#       7     matcher = Matcher(nlp.vocab)
#
# File c:\Users\David\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\__init__.py:51, in load(name, vocab, disable, enable, exclude, config)
#      27 def load(
#      28     name: Union[str, Path],
#      29     *,
#    (...)
#      34     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      35 ) -> Language:
#      36     """Load a spaCy model from an installed package or a local path.
#      37
#      38     name (str): Package name or model path.
#    (...)
#      49     RETURNS (Language): The loaded nlp object.
#      50     """
# ---> 51     return util.load_model(
#      52         name,
#      53         vocab=vocab,
#      54         disable=disable,
#      55         enable=enable,
#      56         exclude=exclude,
#      57         config=config,
#      58     )
#
# File c:\Users\David\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\util.py:472, in load_model(name, vocab, disable, enable, exclude, config)
#     470 if name in OLD_MODEL_SHORTCUTS:
#     471     raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))  # type: ignore[index]
# --> 472 raise IOError(Errors.E050.format(name=name))
#
# OSError: [E050] Can't find model 'en_core_web_sm'. It doesn't seem to be a Python package or a valid path to a data directory.

# %%
city_labels = {
    'New York': 'NY54',
    'Cambridge': 'CMBR',
    'Chicago': 'CHCG',
    'Cleveland': 'CLEV',
    'Raleigh': 'RLGH',
    'Atlanta': 'ATLN',
    'Philadelphia': 'PHLA',
    'Washington': 'WASH',
    'Nashville': 'NSVL',
    'St. Louis': 'STLS',
    'New Orleans': 'NWOR',
    'Houston': 'HSTN',
    'San Antonio': 'SNAN',
    'Dallas': 'DLLS',
    'Orlando': 'ORLD',
    'Denver': 'DNVR',
    'Kansas City': 'KSCY',
    'San Francisco': 'SNFN',
    'Sacramento': 'SCRM',
    'Portland': 'PTLD',
    'Seattle': 'STTL',
    'Salt Lake City': 'SLKC',
    'Los Angeles': 'LA03',
    'San Diego': 'SNDG',
    'Phoenix': 'PHNX'
}

# %%
def generate_query(info):
    # SQL query templates
    queries = {
        'traffic_handling': """
            SELECT f.*, n1.label AS source_label, n2.label AS target_label, e.link_label
            FROM flows f
            JOIN nodes n1 ON f.path LIKE n1.id || ' -> %' OR f.path LIKE '% -> ' || n1.id || ' -> %'
            JOIN nodes n2 ON f.path LIKE '% -> ' || n2.id
            JOIN edges e ON (e.source = n1.id AND e.target = n2.id) OR (e.source = n2.id AND e.target = n1.id)
            WHERE f.organization LIKE '%{}%';
        """,
        'traffic_through': """
            WITH target_org_flows AS (
                SELECT f.*
                FROM flows f
                WHERE f.organization LIKE '%{}%' -- target organization
                AND f.path LIKE CONCAT('% -> ', (SELECT id FROM nodes WHERE label = '{}')) --  target exit city
            ),
            deviation_flows AS (
                SELECT f.*
                FROM target_org_flows f
                WHERE f.path NOT LIKE CONCAT('%',(SELECT id FROM nodes WHERE label = '{}'), '%') -- Replace with the city to check in the path
            )
            SELECT
                CASE
                    WHEN COUNT(*) = 0 THEN CONCAT('Yes, all traffic exiting in ', '{}', ' from ', '{}', ' passes through ', '{}')
                    ELSE CONCAT('No, not all traffic exiting in ', '{}', ' from ', '{}', ' passes through ', '{}', '. Deviations found from the following sources: ', STRING_AGG(DISTINCT source_label, ', '))
                END as traffic_summary
            FROM (
                SELECT f.*, n.label as source_label
                FROM deviation_flows f
                JOIN nodes n ON f.path LIKE CONCAT(n.id, ' -> %')
            ) as deviations;
        """,
        'multiple_egresses': """
            SELECT
                f.organization,
                STRING_AGG(DISTINCT n.label, ', ') AS egress_points
            FROM
                flows f
            JOIN
                nodes n ON f.path LIKE CONCAT('% -> ', n.id)
            GROUP BY
                f.organization
            HAVING
                COUNT(DISTINCT n.id) > 1; 
        """
    }
    
    # replacing city names in info with their corresponding labels
    for key in ['destination', 'middle_hop', 'source']:
        if key in info and info[key] in city_labels:
            info[key] = city_labels[info[key]]

    
    # choose which query to use
    if 'organization' in info and 'destination' in info and 'middle_hop' in info:
        query_template = queries['traffic_through']
        query = query_template.format(info['organization'], info['destination'], info['middle_hop'], info['destination'], info['organization'], info['middle_hop'], info['destination'], info['organization'], info['middle_hop'])
    elif 'organization' in info:
        query_template = queries['traffic_handling']
        query = query_template.format(info['organization'])
    else:
        query = queries['multiple_egresses']

    return query

# example

query = generate_query(info)
print(query)
# Out:
#             SELECT
#                 f.organization,
#                 STRING_AGG(DISTINCT n.label, ', ') AS egress_points
#             FROM
#                 flows f
#             JOIN
#                 nodes n ON f.path LIKE CONCAT('% -> ', n.id)
#             GROUP BY
#                 f.organization
#             HAVING
#                 COUNT(DISTINCT n.id) > 1;

# %%
import psycopg2

db_name = "net2text"
db_user = "postgres"
db_pwd = "anotherone"
db_host = "localhost" 
db_port = "5433"

conn = psycopg2.connect(
    database=db_name, 
    user=db_user, 
    password=db_pwd,
    host=db_host, 
    port=db_port
)

cursor = conn.cursor()

cursor.execute(query)

records = cursor.fetchall()
for record in records:
    print(record)

cursor.close()
conn.close()
# Out:
# ('"24IT SERWIS" Robert Siporski', 'NSVL, SNFN')
# ('"AB-Telecom" Ltd.', 'CHCG, ORLD, RLGH, SLKC, SNAN, STTL')
# ('"ABC Domain" LLC', 'ATLN, HSTN, RLGH, SNDG, SNFN')
# ('"Bulgartel" EAD', 'PHLA, SCRM, SNAN, STLS')
# ('"Everest" Broadcasting Company Ltd', 'ATLN, CHCG, ORLD')
# ('"IR NET" Ltd', 'ATLN, CHCG')
# ('"Interaktivne Kablovske Objedinjene Mreze - I.KOM" D.O.O.', 'CLEV, STLS')
# ('"MAYAK NETWORK" LLC', 'DLLS, DNVR, LA03, PHLA, SCRM')
# ('"OBIT" Ltd.', 'CMBR, DLLS, KSCY, ORLD, PTLD, SNDG, STLS')
# ('"PAIK" Company for Communication and General Trade Importation& Exportation Limited', 'CHCG, CLEV, DNVR, NWOR, SLKC, SNDG, STLS')
# ('"Traffic Broadband Communications" Ltd.', 'ATLN, CLEV, KSCY, PHLA, SNAN, SNFN')
# ('"Tvoi Net" Ltd.', 'HSTN, RLGH')
# ('"Zonata - Natskovi & Sie" Ltd.', 'ATLN, CHCG, CLEV, NY54, SCRM')
# ('012 Smile Communications LTD.', 'DLLS, PHNX, SLKC, SNAN')
# ('013 NetVision Ltd', 'ATLN, CHCG, CMBR, LA03, ORLD, SNAN, SNDG, STTL')
# ('1&1 Internet SE', 'DLLS, SCRM, SLKC, STTL')
# ('1&1 Versatel Deutschland GmbH', 'PHNX, SCRM, SNAN')
# ('10/50 Market St', 'DLLS, DNVR, LA03, ORLD')
# ('10G.KZ LLC', 'CLEV, CMBR, DLLS, DNVR, ORLD, RLGH, SNAN')
# ('116 MADHAV DARSHAN', 'ORLD, PTLD, SNDG')
# ('123.com.ve, C.A.', 'KSCY, LA03, PHNX')
# ('18 Brodie Hall Drive', 'CLEV, DLLS, KSCY, PHNX, RLGH, SLKC, STTL')
# ('18 Science Park Drive', 'KSCY, STTL')
# ('1882914 Ontario Inc', 'DLLS, LA03, SLKC, SNAN, STTL')
# ('1st Class Hosting, LLC', 'LA03, NSVL')
# ('200/4 Young Street', 'KSCY, LA03, NSVL, NWOR, PHLA, SNAN')
# ('21vianet(China) Inc.', 'HSTN, KSCY, LA03, PHLA, SNFN')
# ('22 Stirling St', 'HSTN, PHLA, PHNX')
# ('23Media GmbH', 'DNVR, NSVL, NY54, ORLD, SNDG, STTL')
# ('26th Floor 333/3 Moo 14 Chai Building', 'CHCG, CLEV, NWOR, PHNX, STLS, STTL')
# ('2DAY Telecom LLP', 'CMBR, DNVR, LA03, NWOR, SLKC, STLS')
# ('334,Udyog Vihar', 'HSTN, ORLD, RLGH, SNAN')
# ('3Cinteractive', 'ATLN, DLLS, ORLD, PHLA, PTLD, SCRM, SNDG')
# ('3pleplay Broadband Private Limited', 'DLLS, HSTN, ORLD, PHLA, SCRM, SNDG')
# ('3rd Floor, Kings Court 1, Chino Roces Avenue', 'CHCG, NWOR, NY54, SNAN, STLS')
# ('453 Ladplacout Jorakhaebua', 'DNVR, ORLD, SNDG, SNFN, STLS')
# ('45RU Pty Ltd. Internet Service Provider, Perth, Western Australia.', 'ATLN, CLEV, CMBR, HSTN, LA03, SLKC, STLS')
# ('4DVISION LLC', 'CHCG, NSVL, NY54, SCRM, SNAN, STLS, STTL')
# ('5201 Great America Pkwy # 120', 'ATLN, CHCG, KSCY, PTLD, RLGH, STLS')
# ('5StarNet Limited, Albany AS, Auckland', 'CMBR, PHLA, PHNX, SLKC')
# ('60 Market Square,P.O. Box 364', 'KSCY, NSVL, SCRM')
# ('754th Electronic Systems Group', 'CLEV, NY54, SNFN, STLS')
# (':-) V I V A', 'CLEV, KSCY, LA03, NSVL, NWOR, SNFN')
# ('@YourNet Connection, Inc.', 'ATLN, CHCG, HSTN, PHLA')
# ('A-STAR', 'ATLN, CMBR, LA03, SLKC')
# ('A.C. ROCHA INFORMÁTICA LTDA', 'ATLN, CHCG, DLLS, ORLD, STTL')
# ('A.P. MOLLER - MAERSK A/S', 'ATLN, NSVL, PHLA, PHNX, SNFN, STLS')
# ('A1 Telekom Austria AG', 'ATLN, DLLS, NY54, PTLD, RLGH, SLKC')
# ('A2B IP B.V.', 'HSTN, LA03, PHNX')
# ('AAA National', 'CHCG, CLEV, DNVR, HSTN, LA03, NY54, RLGH')
# ('AAPT Limited', 'SLKC, SNAN, SNDG, STTL')
# ('AB GROUP LLC', 'CHCG, RLGH, SNAN')
# ('ACEM NETWORKS LTDA', 'ATLN, CLEV, DNVR, HSTN, KSCY, PHLA, STLS, STTL')
# ('ACI Worldwide, Inc.', 'CMBR, NSVL')
# ('ACN', 'DLLS, PHLA, PHNX')
# ('ACORUS NETWORKS SAS', 'KSCY, LA03, PHLA')
# ('ACT USA', 'ATLN, HSTN')
# ('ADAMPOLNET Damian Bogucki', 'CLEV, PTLD, RLGH, SCRM, SLKC, STLS')
# ('ADLLink Provedor de Internet Via Radio LTDA', 'CLEV, DLLS, PHLA, PHNX, RLGH')
# ('ADP Brasil LTDA', 'LA03, ORLD, PTLD')
# ('ADT Security Services, Inc.', 'CLEV, CMBR, KSCY, NSVL, ORLD, RLGH, SLKC, SNAN')
# ('AER', 'CHCG, KSCY, STLS')
# ('AFFILIATED COMPUTER SERVICES OF INDIA PRIVATE LIMITED', 'KSCY, NWOR, PHLA, SLKC')
# ('AFGHANTELECOM GOVERNMENT COMMUNICATION NETWORK', 'HSTN, RLGH, SNFN')
# ('AION TECHNOLOGIES PTE LTD', 'DNVR, SNAN')
# ('AIRNET TELECOMUNICATII SRL', 'ATLN, PHLA, PHNX, SLKC, SNAN, STTL')
# ('AKNET Ltd.', 'DNVR, RLGH')
# ('AL-HADATHEH LIL-ITISALAT WA AL-TECHNOLOGIA CO.', 'ATLN, DLLS')
# ('ALARMNET', 'ATLN, CHCG, ORLD, PHLA, PHNX, STLS')
# ('ALEX NET SRL', 'CMBR, HSTN, KSCY, LA03, PHLA, STLS, STTL')
# ('ALIANÇA SISTEMAS DE TELECOMUNICAÇÕES', 'CMBR, DLLS, NSVL, NWOR, PHLA, SLKC, STTL')
# ('ALIDA SRL', 'HSTN, PHNX')
# ('ALLIANCE FOR ACADEMIC INTERNAL MEDICINE', 'CLEV, RLGH')
# ('ALPHASYS - SERVIÇOS E COMUNICAÇÃO LTDA', 'CHCG, DLLS, NSVL, NWOR, SNDG')
# ('ALTANETICA S.L.', 'CHCG, CLEV, DLLS, HSTN, PHNX, SCRM')
# ('ALTIUS Broadband, LLC', 'CHCG, DLLS, LA03, PHLA, SLKC, STTL')
# ('AMA Communications, LLC', 'CLEV, NSVL, NY54, ORLD, PHNX, RLGH, SCRM, SLKC')
# ('AMERICATEL PERU S.A.', 'ATLN, CLEV, DNVR, SNDG, STTL')
# ('AMOREPACIFIC', 'CHCG, DLLS, DNVR, LA03, NY54, SCRM, SNAN')
# ('AMTEL-SVYAZ ZAO', 'DLLS, HSTN, LA03, ORLD, PHLA, SNAN')
# ('ANDORRA TELECOM SAU', 'CMBR, KSCY, NSVL, SCRM')
# ('ANDRA TELECOM', 'LA03, STLS')
# ('ANDRADE & LANDIM TELECOMUNICACOES LTDA', 'CHCG, SCRM')
# ('ANEXIA Internetdienstleistungs GmbH', 'ATLN, CLEV, NSVL, NWOR, PHNX, SLKC')
# ('ANGKOR DATA COMMUNICATION', 'CMBR, PHNX, RLGH, SLKC')
# ('ANJANI BROADBAND SOLUTIONS PVT.LTD.', 'CMBR, KSCY, SLKC, STLS')
# ('ANS Communications', 'DLLS, DNVR, SNAN')
# ('ANTEA S.R.L.', 'CHCG, DLLS, PHLA, SNAN, SNFN, STTL')
# ('ANXeBusiness Corp.', 'CHCG, NWOR')
# ('AOL Transit Data Network', 'DNVR, HSTN, NY54')
# ('AOScloud, LLC.', 'NSVL, SNFN')
# ('AP TRANSIT PTE LTD', 'HSTN, SNAN')
# ('APCS WIP NETWORK,', 'ATLN, CMBR, NSVL, ORLD, SLKC, SNDG')
# ('APEX-CRIMEA Ltd.', 'KSCY, NWOR, PHNX, RLGH, STTL')
# ('APNIC HEITECH ASN', 'NSVL, NY54, ORLD, PHNX, SNFN')
# ('AQUA JUMP SRL', 'PTLD, SLKC')
# ('AREEBA GUINEE SA', 'ORLD, SNAN, SNDG, STTL')
# ('ARENANET TEL COM E SERV EM INF LTDA', 'DLLS, PHNX')
# ('ARISE Services S.A.', 'DLLS, NSVL, NY54, PHNX, RLGH')
# ('ARLINK S.A.', 'NWOR, ORLD, SNFN')
# ('ART-COM Sp. z o.o.', 'CHCG, CLEV, DLLS, NWOR, PHNX')
# ('ARTERIA Networks Corporation', 'CLEV, DLLS, PHNX, PTLD, RLGH, SLKC')
# ('AS Number for CHINANET jiangsu province backbone', 'CMBR, LA03, NSVL, NWOR, RLGH, SLKC, STTL')
# ('AS Number for Interdomain Routing', 'ATLN, CLEV, DNVR, SLKC, STTL')
# ('AS Number from ARIN which uses also for RIPE Resources', 'CLEV, HSTN, KSCY, PTLD, SNAN, STLS')
# ('AS Number of In2cable.com (India) Ltd.', 'CHCG, RLGH')
# ('AS number for New World Telephone Ltd.', 'DNVR, NY54, ORLD, PTLD')
# ('AS263740', 'CHCG, CLEV, SLKC, SNFN')
# ('AS55948.net', 'CMBR, ORLD, RLGH, SLKC, SNAN, SNFN, STLS')
# ('ASA SRL', 'CLEV, NWOR, PHLA, SNFN')
# ('ASN-Digicel', 'LA03, NWOR, NY54, SCRM, SNAN')
# ('ASOCIACION REGIONAL DE COOPERATIVAS DE SERVICIOS PUBLICOS', 'KSCY, NY54, SNAN, SNFN, STLS')
# ('ASSOCIAÇÃO NACIONAL PARA INCLUSÃO DIGITAL - ANID', 'HSTN, NWOR, ORLD, PTLD, STTL')
# ('ASTA-NET S.A.', 'CMBR, DLLS, DNVR, NSVL, NWOR, PHLA')
# ('AT&T Data Communications Services', 'CHCG, KSCY, NWOR, NY54, STLS, STTL')
# ('AT&T Enhanced Network Services', 'CHCG, DNVR, HSTN, PHLA, SLKC, SNFN, STLS')
# ('AT&T Global Network Services, LLC', 'NWOR, SCRM, STLS')
# ('AT&T Internet Services', 'DLLS, LA03, NSVL, PTLD, SLKC')
# ('AT&T Labs, Inc.', 'CHCG, DNVR, HSTN, PHLA, RLGH, SNFN')
# ('AT&T Mobility LLC', 'CHCG, CLEV, KSCY, NWOR, STTL')
# ('AT&T Mobility Puerto Rico', 'CLEV, HSTN, ORLD, SNDG')
# ('AT&T Services, Inc.', 'ATLN, HSTN, NSVL, PHNX, SNFN, STLS')
# ('AT&T WorldNet', 'ORLD, STLS')
# ('AT-I, Inc.', 'DLLS, LA03, PHLA, STTL')
# ('ATEA Sverige AB', 'CHCG, LA03')
# ('ATENTO TELECOM S.I.LTDA', 'DLLS, PHLA')
# ('ATLINK SERVICES, LLC', 'ATLN, SCRM')
# ('ATM S.A.', 'CLEV, NY54')
# ('ATRANET TELECOMUNICACOES LTDA', 'ATLN, DLLS, PHLA, STLS, STTL')
# ('ATW Internet Kft.', 'DLLS, DNVR, NY54, PHNX, RLGH')
# ('ATX Telecommunications Services', 'CHCG, DLLS, NWOR, PTLD')
# ('AUTORIDAD NACIONAL DE LOS SERVICIOS PUBLICOS', 'CHCG, DLLS, LA03, NSVL, SNAN')
# ('AVANGARD TELECOM LLC.', 'CHCG, DLLS, PHLA, RLGH, STTL')
# ('AVEA Iletisim Hizmetleri A.S.', 'CHCG, LA03, NSVL, SNAN, SNFN')
# ('AVICOM Ltd.', 'ATLN, HSTN, NSVL, NY54, PHNX, PTLD, SLKC, STTL')
# ('AWAX Telecom', 'CMBR, DNVR, HSTN, NSVL, PTLD, SNDG, SNFN')
# ('AZ Medien Gruppe (Holding) ENTERPRISE', 'NY54, SCRM, STLS')
# ('AZEDUNET LLC', 'PTLD, STLS')
# ('AZUKI, LLC', 'CHCG, CMBR, NSVL, ORLD, PHNX, SCRM, SNAN')
# ('AbeloHost B.V.', 'KSCY, NSVL, NWOR, PHNX, SNDG')
# ('Abissnet sh.a.', 'CLEV, PHNX')
# ('AboveNet Communications Taiwan', 'ATLN, LA03, NSVL, PHNX, SNAN')
# ('Acantho S.p.a', 'CHCG, ORLD, PHLA, PHNX, SLKC, STTL')
# ('Accelerated Connections Inc.', 'DNVR, KSCY, STLS')
# ('Access America', 'KSCY, PTLD, RLGH, SNDG')
# ('Access Technology, Inc.', 'ORLD, STTL')
# ('Access UK Ltd', 'LA03, NWOR, NY54, ORLD, SNDG, SNFN, STTL')
# ('Acesso10 Telecom', 'SNAN, SNDG')
# ('Achermann ict-services AG', 'ATLN, CHCG, HSTN, LA03, NSVL, PHLA, SCRM, SLKC, STLS, STTL')
# ('Acotel do Brasil LTDA', 'ATLN, CMBR, DNVR, NSVL, NWOR, PTLD')
# ('Actelecom', 'NWOR, ORLD, PHLA, SNFN')
# ('Actiance', 'ORLD, PHNX, SNDG, SNFN')
# ('Action Communications, Security Brazil.', 'NWOR, STTL')
# ('Active Network LLC', 'CHCG, NWOR, STLS')
# ('Actual Network Internet Ltda', 'DLLS, NWOR, PHLA, SLKC, STTL')
# ('Ad Wiser', 'ATLN, CLEV, DLLS, HSTN, PHNX, PTLD, SLKC')
# ('Adapt Services Limited', 'DLLS, NWOR, SNFN')
# ('Adcare Limited', 'DNVR, STTL')
# ('Administracion Nacional de Telecomunicaciones', 'CHCG, PHLA, SNAN')
# ('Admo.net LLC', 'CLEV, STTL')
# ('AdvanceNet Telecom', 'ORLD, PHLA, SNAN, STLS')
# ('Advanced Digital Broadcast spolka z ograniczna odpowiedzialnoscia', 'LA03, NWOR, NY54, RLGH, STLS, STTL')
# ('Advanced Networks & Services Inc.', 'DLLS, HSTN, NY54, PTLD, SLKC')
# ('Advania AB', 'HSTN, ORLD')
# ('Adversor LLP', 'HSTN, NWOR, RLGH, SCRM, SLKC')
# ('AerialCom Srl', 'DLLS, DNVR, LA03, NY54, PTLD')
# ('Aeronet Wireless', 'HSTN, PHNX, PTLD, RLGH, STLS, STTL')
# ('Aetna', 'CLEV, KSCY, LA03, NY54, PHNX, PTLD, SCRM, STLS')
# ('Afilias Canada, Corp.', 'CHCG, CMBR, RLGH')
# ('Agavue LLC', 'ATLN, NSVL, SNAN, SNFN')
# ('Agentia Nationala pentru Locuinte', 'DNVR, SNFN')
# ('Agentia de Administrare a Retelei Nationale de Informatica pentru Educatie si Cercetare', 'ATLN, DLLS, DNVR, HSTN, STLS')
# ('Agriculture bank', 'CMBR, PHLA, STLS')
# ('Ainet Telekommunikations-Netzwerk Betriebs GmbH', 'LA03, NY54, SLKC')
# ('Air Advantage LLC', 'CMBR, HSTN, NY54, PHNX, SNFN, STLS')
# ('Air Medical Group Holdings', 'CHCG, SLKC')
# ('AirIT Services AG', 'HSTN, LA03')
# ('AirMax Communication Ltd', 'CHCG, HSTN, NY54, PHNX, SCRM, STTL')
# ('Aircel Ltd.', 'CMBR, KSCY, ORLD')
# ('Airstream Communications, LLC', 'CMBR, HSTN')
# ('Airtel Networks Limited', 'CHCG, DNVR, PHNX, RLGH')
# ('Airtel Tanzania', 'CHCG, DNVR')
# ('Airtel Uganda Limited', 'CMBR, DLLS, DNVR, ORLD, SNFN')
# ('Aita Comercio de Equipamentos de Informática LTDA', 'PHNX, PTLD')
# ('Akamai International B.V.', 'ATLN, CLEV, DNVR, HSTN, NSVL, NWOR, NY54, PHNX, RLGH, STLS')
# ('Akamai Technologies Tokyo ASN', 'CHCG, CMBR, LA03, NY54, ORLD, SNDG, STTL')
# ('Akamai Technologies, Inc.', 'ATLN, CHCG, NWOR, PHNX')
# ('Akceycom Limited.', 'NSVL, SNDG, STTL')
# ('Alands Telekommunikation Ab', 'CHCG, RLGH, SLKC, SNDG')
# ('Albacom.Amps telecomunicazioni Spa', 'NY54, SNAN')
# ('Alcatel-Lucent', 'ATLN, NWOR, RLGH, SLKC, SNDG, STTL')
# ('Alestra Comunicacion S de RL de CV', 'CHCG, KSCY')
# ('Alfred Health', 'CMBR, KSCY, ORLD')
# ('Alibaba (China) Technology Co., Ltd.', 'DNVR, SCRM')
# ('All Mobile Video Inc', 'ATLN, NSVL, ORLD')
# ('All Points Broadband', 'ATLN, CLEV, CMBR, LA03, PTLD, SNAN, STLS')
# ('Allegiance Communications, LLC', 'NY54, STLS, STTL')
# ('Alliance Broadband Services Pvt. Ltd.', 'CLEV, DLLS, DNVR, PHLA, SLKC, SNAN, STTL')
# ('Allians-Media Ltd', 'CLEV, CMBR, DLLS, HSTN, PTLD, SLKC, SNAN')
# ('Allianz Managed Operations & Services SE', 'CMBR, STLS')
# ('Allo Communications LLC', 'ATLN, CLEV, DNVR, SLKC, SNAN, STTL')
# ('Allstream Corp.', 'CHCG, CLEV, KSCY, LA03, NSVL, NY54, SNAN, STTL')
# ('Alpha Net Telecom Ltd', 'CHCG, HSTN, NWOR')
# ('Alpha Tel S.A.', 'ATLN, DNVR, PTLD')
# ('Alpheus Data Services, L.L.C.', 'CHCG, NWOR, NY54, RLGH')
# ('Alter-NET SRL', 'CMBR, DNVR, RLGH, STLS')
# ('Alterascape, LLC', 'ATLN, CMBR, DNVR, HSTN, SCRM, SLKC, STLS, STTL')
# ('Alternatifbank A.S.', 'LA03, NWOR, PTLD')
# ('AlwaysOn Network Bangladesh Ltd', 'CHCG, KSCY, NY54, ORLD, SNAN')
# ('AmTrust Internet Facing ASN', 'LA03, NWOR, RLGH')
# ('Amalgamated Telecom Holdings Kiribati Ltd', 'NSVL, PHLA, PHNX, SNFN')
# ('Amanah Tech Inc.', 'NSVL, PHLA, SLKC')
# ('Ambit Microsystem Corporation', 'DLLS, LA03, NSVL, NWOR, NY54, SNFN')
# ('American Center for Physics', 'ATLN, LA03, NWOR, NY54, SNFN, STLS')
# ('American Internet Services, LLC.', 'DNVR, LA03, PHLA, RLGH, SNAN, STTL')
# ('American Medical Response, Inc.', 'HSTN, KSCY, NY54, RLGH, SLKC')
# ('Amherst H. Wilder Foundation', 'HSTN, SNAN, SNFN, STLS')
# ('Amnet IT Services Pty Ltd', 'NY54, ORLD, RLGH, STLS, STTL')
# ('Amnet Telecomunicaciones S.A.', 'CHCG, ORLD, SNDG')
# ('Ampernet Telecomunicações Ltda', 'KSCY, ORLD, SCRM')
# ('Amsio B.V.', 'CHCG, DLLS, LA03, NY54')
# ('Anchor Packaging, Inc.', 'SCRM, STTL')
# ('Anderson Marcos Coelho e Cia Ltda - ME', 'SNDG, STLS')
# ('Anheuser-Busch Companies Inc.', 'CMBR, DLLS, KSCY, NSVL, NWOR, RLGH')
# ('Ani Network Pvt Ltd', 'DNVR, PHLA, SNFN')
# ('Antares Kommunikationstechnik AG', 'HSTN, NSVL, NY54, SNAN')
# ('Anycast Global Backbone', 'HSTN, PHNX')
# ('Aonet Provedor de Internet LTDA - ME', 'CLEV, RLGH, SNFN, STTL')
# ('Apn - Processamento de Dados e Soluçoes em Interne', 'ATLN, CMBR, DLLS, DNVR, PHNX, PTLD, STLS')
# ('Apogee Telecom Inc.', 'ATLN, CHCG, CLEV, DNVR, SCRM, SNDG, STTL')
# ('Apollo Online Services Pvt ltd', 'ATLN, CHCG, NY54, ORLD, PHNX, STLS')
# ('AppServe Technologies, LLC', 'ATLN, DNVR, SLKC')
# ('Apple Inc.', 'NSVL, NY54, SNFN, STLS')
# ('Applied Medical Resources Corporation', 'CMBR, DLLS, DNVR, RLGH')
# ('Applied Operations, LLC', 'PTLD, RLGH, SCRM')
# ('Applixia', 'ATLN, CHCG, RLGH')
# ('Aptient Consulting Group Inc.', 'ATLN, CHCG, ORLD, RLGH, SLKC, SNAN, STLS, STTL')
# ('Arcadia Everywhere Network, LLC', 'DLLS, STLS')
# ('Archimedia SRL', 'CMBR, NSVL, ORLD, PHNX, SLKC, SNFN')
# ('Areti Internet Ltd.', 'ATLN, HSTN, PHLA, PHNX, PTLD, SCRM, SLKC')
# ('Aria Shatel Company Ltd', 'ATLN, CLEV, CMBR, KSCY, ORLD, SNDG')
# ('Arialink', 'CHCG, NSVL, PHNX, RLGH')
# ('Ariana Gostar Spadana (PJSC)', 'ATLN, CLEV, NWOR, NY54, SNAN, SNFN')
# ('Ariba, Inc', 'ATLN, CHCG, DLLS, KSCY, PHNX, STTL')
# ('Aristocrat Technologies', 'ATLN, CHCG, ORLD, SNDG, SNFN')
# ('Arkansas State University', 'DNVR, PHLA, SNFN, STTL')
# ('Armenian Datacom Company CJSC', 'ATLN, RLGH, SCRM, SNDG')
# ('Armstrong Cable Services', 'DLLS, SCRM, STTL')
# ('Arris Group, Inc', 'NY54, ORLD, PHNX, SNAN, SNFN, STLS')
# ('ArtPlanet LLC', 'HSTN, NSVL')
# ('Aruba SAS', 'NY54, PHNX')
# ('Asia Pacific Broadband Fixed Lines Co., Ltd.', 'DNVR, LA03, RLGH, SNFN')
# ('Asiasoft Online Pte Ltd', 'CHCG, DNVR, ORLD, SLKC, SNDG, STTL')
# ('Association Internet Traffic Exchange Centre', 'ATLN, LA03, NY54, ORLD, PTLD, SNFN, STLS')
# ('Associação Rede Nacional de Ensino e Pesquisa', 'KSCY, SNAN')
# ('Atalaya Television S.L.', 'NSVL, NY54')
# ('Atlantic Broadband Finance, LLC', 'LA03, PHLA')
# ('Atlantic.net, Inc.', 'CMBR, SLKC, SNAN')
# ('Atos IT Services UK Ltd', 'CMBR, DLLS, HSTN, KSCY, NSVL')
# ('Atos IT Solutions and Services GmbH', 'CHCG, CMBR, KSCY, NSVL, NY54, SLKC, SNDG')
# ('Atria Convergence Technologies Pvt. Ltd.,', 'ATLN, HSTN, NY54, RLGH, SNFN')
# ('Atria Convergence Technologies pvt ltd', 'ATLN, CLEV, DNVR, HSTN, LA03, PTLD, SNFN')
# ('Audio Systems s.c. Robert Grzegorek, Aleksander Cuprych', 'KSCY, NSVL, PHLA, SNAN, SNDG')
# ('Aureon Network Services', 'PHNX, SCRM')
# ('Aurora Technology Management, Inc.', 'ATLN, CLEV, DLLS, NY54, PTLD, SLKC, STLS')
# ('Australia Internet Solutions', 'CHCG, PHNX')
# ('Australian Academic and Reasearch Network (AARNet)', 'ATLN, PHLA, PHNX, SLKC, STTL')
# ('Australian Energy Market Operator LTD', 'DNVR, SNAN')
# ('Austrian Airlines AG', 'CHCG, CMBR, DNVR, HSTN, PHNX')
# ('Automated Financial Systems', 'KSCY, ORLD, PHLA')
# ('Autonomous System Number for Nexlinx', 'ATLN, CHCG, KSCY, ORLD, PHNX, SNFN')
# ('Autoritatea Nationala pentru Administrare si Reglementare in Comunicatii', 'ATLN, DNVR, ORLD, PHLA, SLKC')
# ('Avative Fiber', 'ATLN, NY54, PTLD, SCRM')
# ('Axtel, S.A.B. de C.V.', 'CHCG, CLEV, CMBR, DLLS, SNDG')
# ('Axtelecom Telecomunicações Ltda', 'HSTN, KSCY')
# ('Aztelekom', 'LA03, ORLD, SNFN')
# ('B&WNet Provedor Internet Ltda', 'ATLN, NSVL, PHNX, STTL')
# ('B1 TV CHANNEL S.R.L.', 'CHCG, CMBR, KSCY, SNDG')
# ('B2B Wholesale Pty Ltd', 'KSCY, SNFN')
# ('B3A COMUNICAÇÃO LTDA', 'PHLA, PHNX, RLGH, STTL')
# ('BAE Systems Applied Intelligence US Corp.', 'NSVL, PHLA, SLKC, SNDG, STTL')
# ('BAKCELL LLC', 'HSTN, PTLD, RLGH')
# ('BANCA AFIRME, S.A.', 'KSCY, LA03, NSVL, NY54, ORLD, SCRM')
# ('BANCO EXTERIOR', 'ATLN, NWOR, NY54')
# ('BANCO GUAYAQUIL', 'ATLN, HSTN, LA03, NY54, SCRM, SNAN, STLS, STTL')
# ('BATYEVKA LTD', 'CLEV, DNVR')
# ('BBANDA S.R.L.', 'KSCY, PTLD')
# ('BBCTECH PROVEDOR LTDA', 'ATLN, CHCG, CLEV, NWOR, PHLA, SLKC')
# ('BBN Technologies Corp.', 'HSTN, KSCY, SLKC, SNFN')
# ('BCnet', 'HSTN, KSCY, ORLD')
# ('BD Fibra Telecom Ltda - EPP', 'ATLN, HSTN, NY54, SNDG')
# ('BD Link Communication Ltd', 'NWOR, SNFN')
# ('BDT Capital Partners, LLC', 'ATLN, DNVR, KSCY, ORLD, PHLA, STTL')
# ('BECKMAN COULTER, INC.', 'CMBR, NSVL, NWOR, PHNX, STLS, STTL')
# ('BELL MOBILITY INC.', 'CHCG, NWOR, PTLD, RLGH, SNDG, STLS')
# ('BELWAVE COMMUNICATIONS', 'HSTN, KSCY, NSVL, PHLA')
# ('BEN LOMAND RURAL TELEPHONE COOPERATIVE, INC.', 'ATLN, SNAN, STLS')
# ('BEOTELNET d.o.o. ZRENJANIN', 'CLEV, NY54, SNFN')
# ('BG TEL LIMITED', 'ATLN, CLEV, CMBR, SCRM')
# ('BGC Partners - Singapore', 'NSVL, SNAN')
# ('BHARTI Airtel Ltd.', 'CHCG, DLLS, SNDG')
# ('BI', 'ATLN, CHCG, NSVL, ORLD, PTLD, SLKC, SNDG, STLS')
# ('BIDS Trading L.P.', 'ATLN, CLEV, CMBR, HSTN, LA03, ORLD, SNDG, STLS')
# ('BIT BV', 'DLLS, DNVR, KSCY, NSVL, RLGH')
# ('BITNET ISP AS', 'ATLN, CHCG, ORLD, PHNX, SNDG, SNFN')
# ('BIZNET ISP', 'CHCG, DNVR, NY54, SNAN, STLS')
# ('BNSF Logistics LLC', 'ATLN, DNVR, PHLA, SNAN, SNDG, SNFN, STTL')
# ('BNY ConvergEx Execution Solutions LLC', 'ATLN, HSTN, SNFN')
# ('BOAVISTA- PROVEDOR DE INTERNET E INFORMATICA LTDA', 'PHLA, SNAN, STLS, STTL')
# ('BP America, Inc.', 'CLEV, DLLS, HSTN, NSVL, NY54, RLGH, SCRM')
# ('BPP Teknologi Networks Manager', 'DLLS, ORLD, PHLA, SNFN')
# ('BRD-Groupe Societe Generale SA', 'CMBR, SNAN, STLS')
# ('BRETAGNE TELECOM SAS', 'CLEV, DLLS, NY54, RLGH, SCRM, STTL')
# ('BRIGHT HOUSE NETWORKS, LLC', 'CHCG, ORLD, PHLA, SLKC, SNAN, STLS')
# ('BSE Software GmbH', 'CLEV, PHLA, PHNX, STTL')
# ('BUSAN EDUCATION RESEARCH & INFORMATION CENTER', 'CMBR, HSTN, LA03, RLGH, STLS, STTL')
# ('Babilon-T', 'CLEV, NWOR, PHLA, PHNX, RLGH, SNAN')
# ('Bahnhof Internet AB', 'KSCY, ORLD, RLGH, SCRM')
# ('Baltimore Technology Park, LLC', 'CHCG, CMBR, NSVL, NWOR, SNAN, SNFN')
# ('BanChile Seguros de Vida S.A.', 'ATLN, CMBR, KSCY, SCRM, SNFN')
# ('Banco Credicoop Cooperativo Limitado', 'NY54, SLKC')
# ('Banco Mercantil del Norte S.A., Institucion de Banca Multiple, Grupo Financiero Banorte', 'ATLN, KSCY, PHLA, SNFN')
# ('Bandcon', 'ATLN, HSTN, NY54, SNDG')
# ('Bangladesh Telecommunications Company Limited (BTCL), Nationwide', 'ATLN, NSVL, NY54, SNAN, SNFN')
# ('Banglalion Communications Ltd', 'CLEV, CMBR, DLLS, ORLD, SLKC, SNAN')
# ('Bank of America', 'ATLN, HSTN, LA03, PHLA')
# ('Bank of China Limited', 'CHCG, CLEV, LA03, NY54, SNFN')
# ('Bank of Montreal', 'LA03, SLKC, STTL')
# ('Bank of the West', 'NSVL, NY54')
# ('Banner Serviços de Telecom e Internet Ltda.', 'KSCY, SNDG, SNFN')
# ('Barclays Bank PLC', 'DLLS, RLGH, SLKC')
# ('Barnes & Noble Inc.', 'NY54, RLGH, SLKC, SNAN')
# ('Bart Champagne', 'ATLN, CHCG, KSCY, NY54, SLKC, SNAN, STLS')
# ('Batelco', 'ATLN, KSCY, NWOR, PHLA, SNFN')
# ('Bayerischer Rundfunk', 'CLEV, CMBR, DLLS, SNAN, SNDG, STLS, STTL')
# ('Bayonette AS', 'DLLS, SNFN')
# ('Baystate Health, Inc.', 'CLEV, CMBR, ORLD, SCRM, SNFN, STLS, STTL')
# ('Beacon Technologies, Inc', 'PTLD, STLS')
# ('Beamspeed', 'PHLA, PHNX, PTLD, SCRM, SNAN')
# ('Beijing Baidu Netcom Science and Technology Co., Ltd.', 'ATLN, CLEV, NWOR, NY54, SNAN, SNFN')
# ('Beijing Blue I.T Technologies Co.,Ltd.', 'DNVR, LA03')
# ('Beijing Capital Public Information Platform', 'CLEV, CMBR, ORLD, SNDG, SNFN')
# ('Beijing CheeryZone Scitech Co.,Ltd', 'DLLS, NY54, RLGH, SNDG, SNFN')
# ('Beijing Guanghuan Xinwang Digital', 'CLEV, NY54, PTLD, SCRM, SNAN, STLS')
# ('Beijing Kuancom Network Technology Co.,Ltd.', 'DLLS, PHLA, PHNX, PTLD, SNFN')
# ('Beijing Topnew Info&Tech co,.LTD.', 'DLLS, LA03, NSVL, PHLA, PHNX, RLGH, SNFN')
# ('Bekkers Information Technology', 'CHCG, DLLS, NSVL, PHNX, STTL')
# ('Belize Telemedia Limited', 'CHCG, DLLS, PHNX, SLKC, STLS, STTL')
# ('Bell Canada', 'ATLN, CHCG, CLEV, NWOR, NY54, PHLA, PHNX, SNFN')
# ('Bell Techlogix', 'CHCG, DLLS, HSTN, NY54, RLGH, SNDG')
# ('Bell Teleservices India Pvt Ltd., ISP having own OFC network in Bangalore, India.', 'CHCG, DLLS, PHLA, SLKC')
# ('BellSouth.net Inc.', 'CLEV, SNFN')
# ('Bella Mia, Inc.', 'CHCG, NY54, RLGH, STLS, STTL')
# ('Bemis', 'CLEV, HSTN, LA03, NY54, SLKC, SNFN')
# ('BeotelNet-ISP d.o.o', 'NY54, ORLD, PTLD, SCRM, STLS')
# ('Bergslagens Kommunalteknik', 'NWOR, RLGH')
# ('Best Telecom SRL', 'CLEV, NY54')
# ('Bevcomm', 'CHCG, DNVR, RLGH, SLKC, SNAN, SNDG')
# ('Beyond Hosting, LLC', 'CLEV, DNVR, KSCY, LA03, PHLA, RLGH, SNAN, STTL')
# ('Beyond The Network America, Inc.', 'DLLS, LA03, NWOR, SLKC, STTL')
# ('Bezeq International-Ltd', 'CLEV, DNVR, NWOR, SNAN, STTL')
# ('Bharti Airtel (Ghana) Limited', 'LA03, NSVL, ORLD, PHLA, PTLD, STLS')
# ('Bharti Airtel Ltd. AS for GPRS Service', 'DNVR, LA03')
# ('Bharti Airtel Ltd., TELEMEDIA Services, for SMB customers', 'CHCG, STLS')
# ('Bharti Telesonic Ltd', 'KSCY, PHLA')
# ('Bicos Computer GmbH', 'CLEV, PHNX, PTLD')
# ('BigAir Group,', 'ORLD, SNDG')
# ('Bigband Sdn Bhd', 'NY54, SLKC')
# ('Bijoy Online Ltd. Multihome Internet Service Provider', 'HSTN, LA03, PHLA, SLKC')
# ('BioNet LLC', 'ATLN, STTL')
# ('Biotronik SE & Co.KG', 'DNVR, LA03, NWOR, PTLD, SNAN')
# ('Bioware Ireland Ltd', 'CHCG, NY54')
# ('Birch Telecom, Inc.', 'CLEV, DLLS, KSCY, NWOR, RLGH, SNAN, SNFN')
# ('Bit-isle Co.,Ltd.', 'DLLS, NSVL, SLKC, SNDG')
# ('Bitmax, LLC', 'ATLN, CMBR, NWOR, SNDG')
# ('Bitskin GmbH', 'CMBR, LA03')
# ('Bittel Telecom Pvt Ltd', 'CHCG, CLEV, NY54, SLKC, SNAN')
# ('Black Box Network Services', 'CHCG, HSTN, NSVL, PHLA, PHNX, SNFN')
# ('Black Knight IP Holding Company, LLC', 'DLLS, NSVL, ORLD, SLKC, STLS')
# ('BlackBerry Limited', 'CMBR, NY54, PHNX, SNDG')
# ('BlackSun Inc.', 'ATLN, HSTN')
# ('Bleta Sh.p.k', 'HSTN, PHLA, PHNX, PTLD, SLKC, SNFN')
# ('Blizoo Media and Broadband EAD', 'CHCG, NWOR')
# ('Blizzard Entertainment, Inc', 'ATLN, CMBR, DLLS, ORLD, PHNX, PTLD, SNFN')
# ('Block B05/3 Garden City Business Centre', 'CHCG, HSTN, LA03, RLGH')
# ('Bloomberg, LP', 'DNVR, LA03, ORLD, PHLA, SNAN')
# ('Bloomip Inc.', 'CHCG, CMBR, KSCY, PHLA, SLKC')
# ('Blue Lotus Support Services Pvt Ltd', 'CHCG, CLEV, DLLS, KSCY, LA03, RLGH, SNAN, SNFN')
# ('Bluewave Internet Ltd', 'ATLN, PHLA, SCRM, SNAN')
# ('Bogazici University', 'HSTN, PHLA, SLKC, STTL')
# ('Bogor Agricultural University', 'NWOR, ORLD')
# ('Border States Industries', 'LA03, NSVL')
# ('Botswana Telecommunications Corporation', 'ATLN, CHCG, SNDG')
# ('Bouygues Telecom SA', 'CLEV, SNFN')
# ('Bowling Green Municipal Utilities', 'ATLN, DNVR, PTLD')
# ('Box.com', 'HSTN, ORLD')
# ('Bradler & Krantz GmbH & Co. KG', 'ATLN, CLEV, SLKC, STLS, STTL')
# ('Brain Net', 'DLLS, LA03, NY54')
# ('Braintrust Ltd', 'DLLS, LA03, NY54, STTL')
# ('Branch of Netnam Company in Ho Chi Minh City', 'NSVL, SLKC')
# ('Brand Developers Limited', 'ATLN, CHCG, CLEV, PHLA, SCRM')
# ('Brantley Telephone Company, Inc.', 'CLEV, DLLS, NWOR, NY54, PHNX, RLGH, STLS')
# ('Brasil Telecom S/A - Filial Distrito Federal', 'HSTN, SCRM, SNAN, STLS')
# ('Brasil Telecomunicações S.A.', 'ATLN, DLLS, PHNX, SLKC')
# ('Brennan IT', 'CHCG, CLEV, NSVL, NWOR, PHNX')
# ('BrianTel SRL', 'CHCG, DLLS, RLGH, SNFN')
# ('BrightNet Oklahoma', 'ATLN, CHCG, CLEV, KSCY, LA03, NY54, RLGH, SNFN, STTL')
# ('Bristol-Myers Squibb Company', 'CLEV, DNVR, HSTN, NSVL, NY54, PHNX, PTLD')
# ('British Columbia Lottery Corp', 'CLEV, SNDG')
# ('British Telecommunications PLC', 'ATLN, CHCG, DLLS, LA03, PHLA, SNAN, SNFN, STLS')
# ('British Telecommunications plc', 'CLEV, CMBR, DLLS, DNVR, HSTN, LA03, SNFN')
# ('BroadSoft, Inc.', 'LA03, NY54')
# ('Broadband Dynamics, LLC', 'CHCG, NY54')
# ('Broadband Pacenet Pvt. Ltd', 'SCRM, STTL')
# ('Broadnet AS', 'CHCG, NWOR, SNAN, STLS')
# ('Broadview Networks, Inc.', 'ATLN, NY54, SCRM')
# ('BrokerCreditService Ltd.', 'CHCG, DLLS, NY54, ORLD, STLS')
# ('BruNet - Telekom Brunei Berhad', 'ATLN, CHCG, PHLA, PHNX, STLS')
# ('Bryn Mawr College', 'CHCG, DLLS, KSCY, PHLA, PHNX, STLS')
# ('Bualuang-ventures-company-limited', 'ATLN, DNVR, LA03, ORLD, PHNX, PTLD')
# ('Bulgarian Telecommunications Company Plc.', 'CMBR, LA03, NY54, SNAN, SNFN')
# ('Bulloch County Rural Telephone Cooperative, Inc.', 'PHNX, SNDG')
# ('Bullseye Telecom', 'CHCG, DNVR, LA03, ORLD, STLS')
# ('Bunt Studio SRL', 'PHNX, SLKC')
# ('Buroserv Australia Pty Ltd', 'ATLN, DLLS, PHLA, SNDG, STLS, STTL')
# ('Business Only Broadband', 'CLEV, STLS')
# ('ByteSolution S.A. (WispSolution Internet)', 'CHCG, NWOR, ORLD')
# ('C.S.P.S Carta Solutions Processing Services (CYPRUS)LTD', 'CLEV, HSTN, LA03, NWOR, SNDG, STLS')
# ('C24 Ltd', 'CLEV, DNVR, LA03, NY54, ORLD, SLKC')
# ('C3 Desenvolvimento de Sistemas Computacionais', 'NY54, SNFN')
# ('C48 Okhla Industrial Estate, New Delhi-110020', 'ATLN, KSCY, LA03, STLS')
# ('CA, Inc.', 'DLLS, KSCY, ORLD, PHLA, SCRM, SNDG, STTL')
# ('CABLE ONE, INC.', 'CLEV, HSTN, NY54, SLKC')
# ('CABLECOLOR S.A.', 'DLLS, PHLA, SNFN')
# ('CABLEVISION S.A.', 'ATLN, CLEV, CMBR, HSTN, KSCY, LA03, PHLA, SCRM')
# ('CAIXA ECONOMICA FEDERAL', 'DLLS, LA03, NSVL, NY54, SNAN, STLS')
# ('CAIXA GERAL DE DEPOSITOS, SA', 'PHLA, SNFN')
# ('CAMEROON TELECOMMUNICATIONS NETWORK', 'CHCG, KSCY, PTLD, RLGH, SNAN')
# ('CANTV Servicios, Venezuela', 'SNDG, SNFN')
# ('CARANGOLA TELECOMUNICACOES LTDA-EPP', 'ORLD, PHLA, RLGH, STLS')
# ('CARRIERENABLER S.L.', 'DLLS, DNVR, PHLA, PTLD, RLGH')
# ('CASA ATC SERVIZI SRL', 'ATLN, HSTN')
# ('CAVALIERS OPERATING CO LLC.', 'CHCG, DLLS, RLGH, SNAN')
# ('CBC EMEA LTD', 'CMBR, ORLD, PTLD, RLGH, SLKC, STLS')
# ('CBEYOND COMMUNICATIONS, LLC', 'ATLN, CLEV, PHNX, SLKC, SNAN')
# ('CBS Interactive Inc.', 'ATLN, NWOR, SCRM')
# ('CCC Information Services Inc.', 'ATLN, CHCG, KSCY, ORLD, SLKC, STLS, STTL')
# ('CCI Communications LLC', 'DLLS, SLKC, STLS')
# ('CCM Benchmark Group SAS', 'LA03, NWOR, NY54, SNFN, STLS')
# ('CCS', 'KSCY, STLS')
# ('CDM', 'ATLN, CHCG, SNAN, SNDG, SNFN, STLS')
# ('CDNetworks Inc.', 'CMBR, NSVL, PTLD, SLKC, STLS')
# ('CDNvideo LLC', 'DNVR, HSTN')
# ('CEDNET PROVEDOR INTERNET', 'DLLS, HSTN, NSVL, PHNX, SCRM')
# ('CEGER', 'CHCG, NSVL, NY54')
# ('CELANTE SERVICOS DE TELECOMUNICACOES LTDA - EPP', 'DLLS, ORLD')
# ('CENTRAL ARIZONA COLLEGE', 'CHCG, SNFN')
# ('CENTRE FOR DEVELOPMENT OF TELEMATICS', 'ATLN, NWOR, PHNX, PTLD, SNFN')
# ('CENTROSUR', 'PHLA, SNAN')
# ('CERIDIAN', 'CHCG, CMBR, HSTN, NY54, SNAN, STLS, STTL')
# ('CERIZ SASU', 'CMBR, PHLA, PHNX, SNFN, STLS')
# ('CERN - European Organization for Nuclear Research', 'CLEV, CMBR, DLLS, NSVL, NWOR, STTL')
# ('CERNET2 IX at Peking University', 'CMBR, DLLS, NSVL, NWOR, RLGH, SLKC, STTL')
# ('CERTTO TELECOMUNICAÇÕES LTDA EPP.', 'DLLS, LA03, NY54, PTLD, SNFN')
# ('CFH CABLE INC', 'CMBR, PTLD, SNDG')
# ('CGI TECHNOLOGIES AND SOLUTIONS INC.', 'ATLN, HSTN, LA03, PHNX, STLS')
# ('CH-NET S.R.L.', 'CLEV, DLLS, LA03, NY54, SCRM, STTL')
# ('CHINANET Guangdong province Dongguan MAN network', 'ATLN, CHCG, PTLD, SLKC, STLS')
# ('CHINANET Guangdong province network', 'CHCG, STLS')
# ('CHINANET Jiangx province IDC network', 'DLLS, SNDG')
# ('CHINANET SiChuan Telecom Internet Data Center', 'CMBR, RLGH, SNAN, STTL')
# ('CHINANET Sichuan province Chengdu MAN network', 'KSCY, NWOR, PHLA, SLKC, SNDG')
# ('CHML Web Services SRL', 'ATLN, CHCG')
# ('CHP Zarko Alexandr Ivanovich', 'CMBR, ORLD')
# ('CHRONOS SERV INVEST CONSTRUCT SRL', 'ATLN, CLEV, SNDG')
# ('CIK Telecom INC', 'ATLN, CHCG, DLLS, HSTN, PHNX, SNFN')
# ('CINTIA AUXILIADORA DE ALCANTARA BARBOSA - ME', 'ATLN, DNVR, HSTN, PTLD, SCRM, SNDG')
# ('CIRA Canadian Internet Registration Authority Autorit Canadienne pour les enregistrements Internet', 'CHCG, ORLD, PHLA, SNFN, STLS')
# ('CIRCUITOS ALJARAFE, S.L.', 'ATLN, DLLS, LA03, NY54, ORLD')
# ('CITIC Telecom International CPC Limited', 'ATLN, CLEV, CMBR, HSTN, PHNX, SLKC, SNFN')
# ('CITISTREET', 'CHCG, CLEV, DLLS, NWOR, NY54, PHNX')
# ('CIZGI TELEKOMUNIKASYON ANONIM SIRKETI', 'HSTN, STLS, STTL')
# ('CJ-HELLOVISION', 'CMBR, DNVR, NWOR, NY54, SCRM, SLKC')
# ('CJONLINE ISP India', 'DLLS, KSCY, LA03, STTL')
# ('CJSC "UKRGAZ-ENERGO"', 'CHCG, NWOR, ORLD')
# ('CJSC ENGINET', 'DLLS, HSTN, KSCY, PTLD, SNAN')
# ('CJSC IFD Kapital', 'CLEV, DLLS, PHLA, RLGH, SCRM, SNAN')
# ('CJSC Rosintel', 'LA03, NY54, ORLD, PHNX, SNFN')
# ('CJSC TransVostokTelecom', 'CHCG, HSTN, LA03, NY54, SLKC')
# ('CLARA ONLINE, Inc.', 'DNVR, HSTN, NY54, PTLD, SNDG, STLS')
# ('CLARO S.A.', 'ATLN, CHCG, CMBR, DLLS, HSTN, KSCY, NSVL, ORLD, PTLD, RLGH, SCRM, SLKC, SNAN, SNDG, SNFN')
# ('CLOUDITALIA TELECOMUNICAZIONI S.P.A.', 'ATLN, CLEV, LA03, NWOR, PTLD, RLGH')
# ('CM Groep B.V.', 'CMBR, HSTN, LA03, NY54, SLKC, SNDG')
# ('CMA CGM SA', 'CMBR, DNVR, HSTN, KSCY, LA03, NSVL, SNFN')
# ('CMA Consultoria Metodos Assessoria e Mercantil S/A', 'CHCG, DLLS, LA03, PHNX, STLS')
# ('CMB', 'LA03, NWOR, ORLD, PHNX, SLKC')
# ('CMB Daejeon Broadcasting Co,.Ltd', 'CMBR, ORLD, STTL')
# ('CMB TAEGU BROADCASTING', 'DLLS, NY54, PHLA, SNAN')
# ('CMC Telecom Infrastructure Company', 'NSVL, PTLD')
# ('CMH Services Inc.', 'HSTN, LA03, RLGH, SCRM, SLKC, STLS')
# ('CNCGROUP Jitong IP network', 'ATLN, CLEV, HSTN, LA03')
# ('CNETWORK SRL', 'CHCG, SNFN')
# ('CNSERVERS LLC', 'ATLN, CLEV, ORLD, PHLA, SNAN, SNFN')
# ('CO.PA.CO.', 'ATLN, CMBR, DLLS, KSCY, PTLD, SNAN, SNFN')
# ('COLOMBIA TELECOMUNICACIONES S.A. ESP', 'DLLS, NY54, STLS')
# ('COLT Technology Services Group Limited', 'LA03, NWOR, NY54, PHNX, RLGH, SNFN')
# ('COM-IN Telekommunikations GmbH', 'NWOR, RLGH')
# ('COMCEL S.A.', 'CHCG, CLEV, NWOR, NY54, PHLA, PHNX, SLKC, SNFN')
# ('COMMNET WIRELESS LLC', 'ATLN, CMBR, HSTN, KSCY, LA03, PTLD, RLGH')
# ('COMPAÑIA DE CIRCUITOS CERRADOS S.A.', 'ATLN, CHCG, PHLA, PHNX, SNFN')
# ('COMPLETEL SAS France', 'CMBR, NSVL, ORLD, SNFN')
# ('COMPUGRAF Serviços Ltda', 'CHCG, CLEV, DLLS, SLKC, STTL')
# ('CONECTSUL - COMERCIO E SERVICOS LTDA', 'HSTN, LA03, NY54, SCRM, STLS, STTL')
# ('CONOPCO, INC.', 'CHCG, ORLD, PTLD, RLGH')
# ('CONSULNETWORK LTDA', 'DNVR, ORLD, PHLA, PHNX, RLGH, SLKC')
# ('CONTENT DELIVERY NETWORK LTD', 'CLEV, LA03, STLS')
# ('COOPERATIVA DE SERVICIOS MULTIPLES REG', 'NY54, SNDG')
# ('CORE TELECOM & IT LTDA', 'DLLS, NSVL, ORLD, SNAN')
# ('CORETX MANAGE LIMITED', 'ATLN, CLEV, SCRM, SNAN, SNFN')
# ('CORPICO LTDA', 'ATLN, SNDG, SNFN, STLS')
# ('CPS', 'CHCG, KSCY, NWOR, SNDG, SNFN')
# ('CREDIT-SUISSE-GROUP', 'CMBR, HSTN, KSCY, LA03, RLGH, STLS')
# ('CS Sales Sweden AB', 'CMBR, DNVR, HSTN, PHLA, PHNX, SLKC, STTL')
# ('CSL Computer Service Langenbach GmbH', 'CHCG, NY54, SCRM, SNAN')
# ('CSLOXINFO Project for IAG Insurance', 'CHCG, CLEV, SCRM, SNAN')
# ('CTB Media Inc.', 'ATLN, NSVL, PHNX, SNAN, SNFN')
# ('CTBA TELECOM', 'ATLN, PHNX')
# ('CTC Transmisiones Regionales S.A.', 'CHCG, CLEV, RLGH, SLKC, STLS')
# ('CTS Eventim Solutions GmbH', 'ATLN, LA03, SNDG, SNFN')
# ('CU*Answers, Inc.', 'HSTN, PHNX')
# ('CVF S.A', 'ATLN, DLLS, KSCY, RLGH, SNAN, SNDG, STTL')
# ('Cable & Wireless (Seychelles) Ltd', 'ATLN, DNVR, ORLD, PHNX, RLGH, STLS')
# ('Cable & Wireless UK P.U.C.', 'CHCG, HSTN, NY54')
# ('Cable Axion Digitel Inc.', 'NSVL, ORLD, PHNX, PTLD, SLKC')
# ('Cable ISP in India', 'ATLN, CHCG, CLEV')
# ('Cable Onda', 'HSTN, KSCY, NSVL, NY54, PHNX')
# ('Cable Tica', 'CHCG, LA03, PHLA')
# ('Cable and Wireless, Turks and Caicos', 'ATLN, NY54, SNAN, STLS')
# ('Cablecom Networking Limited', 'CHCG, DLLS, NWOR, NY54, SNAN')
# ('Cablelynx', 'KSCY, PHLA, SLKC, SNDG, STTL')
# ('Cablemas Telecomunicaciones SA de CV', 'CHCG, CMBR, DLLS, HSTN, KSCY, LA03, NY54, ORLD, PHLA, PHNX, PTLD, SNAN, SNFN, STLS, STTL')
# ('Cablenet S.A', 'DLLS, HSTN, NSVL, NY54, PHNX, PTLD')
# ('Cablevision Systems Corp.', 'DLLS, LA03, NY54, SNFN')
# ('Cabovisao, televisao por cabovisao, sa', 'ATLN, CHCG, CLEV, LA03, ORLD, SNAN, SNFN, STLS')
# ('Cached', 'CLEV, LA03, SNFN, STLS')
# ('Cal.net, Inc.', 'CLEV, HSTN, PHLA, SNFN, STTL')
# ('CalTech Software Systems Inc.', 'NSVL, ORLD, RLGH, SNAN, SNFN')
# ('California Education and Research Federation Network', 'KSCY, LA03, NSVL, NWOR, PHLA, SNAN, STTL')
# ('California State University, Office of the Chancellor', 'CHCG, HSTN, LA03, NY54')
# ('Call U Communications Ltd.', 'NWOR, NY54, PTLD, SLKC, SNFN')
# ('CallSat International Telecommunications Ltd.', 'CLEV, NY54, ORLD, SLKC, STTL')
# ('Canal + Telecom SAS', 'CHCG, NY54, PHNX, STLS, STTL')
# ('Canal S SRL', 'NSVL, SNDG')
# ('Canarie Inc', 'CMBR, SLKC, SNAN')
# ('Canby Telephone Association', 'CLEV, DLLS, LA03, NY54, RLGH, STLS')
# ('Canyon Country Communications, Inc.', 'ATLN, DLLS, KSCY, LA03, NY54, PTLD')
# ('Capital One Financial Corporation', 'PHLA, SNFN')
# ('Capture Network Systems Pvt Ltd', 'DLLS, PHLA, SNDG')
# ('CareFusion Corporation', 'LA03, NWOR, PHLA, SCRM')
# ('Cargill Incorporated', 'CLEV, HSTN, SNFN')
# ('CariNet, Inc.', 'DNVR, NWOR, NY54, SLKC')
# ('Carroll-Net, Inc.', 'ATLN, CLEV, CMBR, HSTN, RLGH, SNDG, STTL')
# ('Cassava Enterprises Ltd.', 'ATLN, CHCG, DNVR, ORLD, PHLA')
# ('Castle Access Inc', 'KSCY, NSVL, NWOR, PHNX, RLGH, SNFN')
# ('Cataguases Net Ltda', 'DNVR, LA03, NSVL, SNFN')
# ('Caviar Group NV', 'HSTN, PHNX, SLKC')
# ('Cedar Networks', 'LA03, SNFN')
# ('Celcom Internet Service Provider', 'DLLS, RLGH')
# ('Celito Communications Inc.', 'ATLN, PHNX, SLKC')
# ('Cellco Partnership DBA Verizon Wireless', 'ATLN, DLLS, NWOR, PHLA, PHNX, SNFN, STLS, STTL')
# ('Cellcom Guinea', 'DLLS, DNVR')
# ('Cellcom Telecommunications Inc.', 'HSTN, PHLA, SNFN')
# ('Centauri Communications', 'NWOR, PHLA, RLGH, SCRM, STTL')
# ('Center for Diagnostic Imaging', 'CMBR, DLLS, RLGH, SLKC, SNDG, SNFN')
# ('Central 8 Limitada', 'ATLN, DNVR, HSTN, LA03, NSVL, PHLA, SLKC, SNFN')
# ('Central Soluções em TI e Internet', 'ATLN, NSVL, NY54, ORLD, PHNX, SNFN, STTL')
# ('Centre de Telecomuncaciones i Tecnologies de la Informacias de la Generalitat de Catalunya', 'CLEV, LA03, PHLA')
# ('Centrilogic, Inc.', 'CHCG, CLEV, HSTN, STLS')
# ('Centro de Informacoes Tecnologia de Macau', 'LA03, NWOR, PHLA, PHNX, SNFN, STLS')
# ('Cesky Bezdrat, s.r.o.', 'CMBR, DNVR, ORLD, PHLA, PTLD')
# ('Champaign Telephone Company, INC.', 'LA03, NSVL, ORLD, SLKC')
# ('ChangZhou Bitcomm Software Technology Co., Limited', 'ORLD, SNFN')
# ('Changwon National University', 'ATLN, NWOR, NY54, PHNX')
# ('Charlotte-Mecklenburg Schools', 'CHCG, CLEV, SNAN')
# ('Charter Communications', 'CHCG, DLLS')
# ('Check Point Software Technologies, Inc.', 'CMBR, PHLA')
# ('CheckFree Corporation', 'DNVR, LA03, NY54, PTLD')
# ('Cheiljedang.Co.Inc.', 'ORLD, PHLA, PTLD, SCRM, SNDG, STLS')
# ('China Education and Research Network Center', 'PHLA, PTLD, SLKC, STLS')
# ('China Internet Network Infomation Center', 'LA03, PHLA, SNAN, SNFN')
# ('China Mobile Communicaitons Corporation', 'DNVR, ORLD, PHNX, SNDG')
# ('China Mobile Hong Kong Company Limited', 'CLEV, CMBR, HSTN, PHNX, RLGH, SNFN')
# ('China Mobile International Limited', 'ATLN, SLKC')
# ('China Telecom(Group)', 'CHCG, DLLS, DNVR, HSTN')
# ('China TieTong Telecommunications Corporation', 'ATLN, DNVR, HSTN, PHLA, SNDG, SNFN')
# ('China Unicom IP network', 'ATLN, CHCG, HSTN, PHNX, SCRM, SLKC, SNFN')
# ('Chonbuk National University', 'CHCG, CLEV, NWOR')
# ('Choopa, LLC', 'CLEV, DNVR, HSTN, PHLA, PTLD, RLGH, SCRM')
# ('Chr. Hansen Malaysia Sdn Bhd', 'ATLN, KSCY, NY54, ORLD, PHNX, SLKC, STLS, STTL')
# ('Christ College Christchurch ASN', 'DLLS, KSCY')
# ('Christian Broadcasting Network, Inc.', 'LA03, STLS, STTL')
# ('Chugach Electric Association, Inc.', 'PTLD, SLKC')
# ('Chunghwa Telecom Global, INC', 'CLEV, PHNX')
# ('Ci Telecom Autonomous system number', 'CHCG, HSTN, KSCY, NY54, PHNX, PTLD, SNFN, STLS')
# ('Cincinnati Bell Telephone Company LLC', 'CHCG, NSVL, SNFN')
# ('CipherSpace GmbH', 'HSTN, KSCY, LA03, NY54')
# ('Cipherwave', 'CMBR, DNVR, SLKC, SNDG')
# ('Circle Computer Resources, Inc.', 'CHCG, CMBR, DLLS, RLGH, SLKC, SNAN, STLS')
# ('Cisco Systems, Inc.', 'LA03, NWOR, RLGH, SNFN')
# ('Ciss Consultoria em Informatica Serv e Softw S/A', 'NWOR, NY54, SCRM, STLS')
# ('Citizens Property Insurance Corporation', 'CLEV, KSCY, STLS')
# ('Citrix Online LLC', 'HSTN, NWOR, PHLA, SCRM, STLS')
# ('City Network Hosting AB', 'CHCG, DLLS, NSVL, PHNX, RLGH, SLKC, SNAN, STTL')
# ('City of Burbank', 'ATLN, DLLS, NWOR, PHLA, SLKC, STLS')
# ('City of Houston', 'ATLN, CHCG')
# ('City of Phoenix', 'DLLS, DNVR, PHLA, PHNX')
# ('City of Rancho Cucamonga', 'DLLS, DNVR, PHNX, RLGH')
# ('Cityfibre Limited', 'CLEV, DLLS, DNVR, HSTN, KSCY')
# ('Civiq Smartscapes, LLC', 'DNVR, NSVL, PHLA, SNFN')
# ('Clarity Telecom LLC', 'ATLN, NSVL, NY54, PHNX, RLGH, SNFN, STTL')
# ('Claro Panamá S.A.', 'CHCG, DNVR, LA03, NWOR, ORLD, PHLA, SLKC, SNDG')
# ('Claro S/A', 'ATLN, DNVR, PHLA, SLKC')
# ('Clear Networks Pty Ltd', 'DLLS, HSTN, LA03, NY54, PHLA, PTLD, RLGH, SCRM, SNAN')
# ('ClearBlue Technologies', 'DLLS, DNVR, PHNX, SLKC, SNFN')
# ('ClearLink', 'CLEV, HSTN, PHLA, STTL')
# ('Cleartalk', 'LA03, NSVL, NWOR, NY54, SLKC, STTL')
# ('Click.com telecomunicações ltda-me', 'ATLN, CMBR, KSCY, STTL')
# ('Closed Joint Stock Company TransTeleCom', 'NWOR, RLGH, SNAN')
# ('Closed Joint-stock company Avantel', 'CHCG, HSTN, PHLA')
# ('Cloud DNS Ltd', 'CHCG, DNVR, PTLD, SCRM')
# ('CloudAccess.net, LLC', 'ATLN, DNVR, NWOR, PHNX')
# ('CloudRadium L.L.C', 'CLEV, DLLS, ORLD, PHNX, RLGH, SNFN')
# ('Cloudie Limited', 'SLKC, SNFN')
# ('Cnergee Cloud Technology Solutions LLP', 'ATLN, CLEV, DLLS, NY54')
# ('Co-Mo Comm Inc', 'HSTN, SNDG')
# ('Cobourg Networks Inc.', 'KSCY, NWOR, STTL')
# ('Cobranet Limited', 'CHCG, CLEV, KSCY, NWOR, RLGH, SLKC, SNAN')
# ('Cogent Communications', 'ORLD, PHNX, SLKC, SNAN, STLS')
# ('Cognizant Technology Solutions India Pvt Ltd,', 'PTLD, RLGH')
# ('Cold Spring Harbor Laboratory', 'KSCY, LA03, NSVL, STTL')
# ('Colo Solutions, Inc.', 'CHCG, DLLS, HSTN, PHNX, STTL')
# ('Colo4, LLC', 'DLLS, RLGH')
# ('ColoCrossing', 'ATLN, CMBR, DLLS, LA03, NY54, PTLD, SCRM, STTL')
# ('Colombia Móvil', 'KSCY, PHNX, PTLD, STLS')
# ('Colorado College', 'DLLS, SCRM')
# ('Colruyt Group Services NV', 'CHCG, STLS')
# ('Colsecor Cooperativa Limitada', 'CHCG, CMBR, NY54, ORLD, SNFN')
# ('Colt Technology Services RO SRL', 'KSCY, RLGH, SNDG, STTL')
# ('Columbia Basin Broadband Corporation', 'LA03, NWOR, STLS')
# ('Columbus Communications Curacao NV', 'LA03, PHLA, STLS, STTL')
# ('Columbus Networks Puerto Rico', 'DLLS, LA03, PHLA, SLKC, STLS')
# ('Columbus Networks USA, Inc.', 'CMBR, SNFN')
# ('Columbus Telephone Company Incorporated', 'CHCG, DLLS, ORLD, RLGH, SNAN')
# ('Com4 Data Center Ltda EPP', 'CMBR, SLKC')
# ('ComTec Cloud', 'ATLN, CHCG, CMBR, LA03, ORLD, PHNX, STLS')
# ('Combined Soft BD', 'ATLN, DLLS, SNDG, SNFN')
# ('Combo Livre', 'HSTN, SCRM, SNDG, SNFN, STLS')
# ('Comcast Cable Communications, LLC', 'HSTN, LA03')
# ('Commercial Network Services', 'PHLA, SNDG')
# ('Commerzbank Aktiengesellschaft', 'ATLN, NSVL, NWOR, NY54, SLKC, SNAN, SNFN, STTL')
# ('Commonwealth of Massachusetts', 'ATLN, DLLS')
# ('Comms365 Limited', 'CHCG, CLEV, DLLS, KSCY, NSVL, NWOR, SCRM, SNFN')
# ('Communication and International Trading Company S.A.R.L', 'CMBR, DNVR, SNDG')
# ('Communications Plus, Inc.', 'KSCY, NWOR')
# ('Communications and IT Research Institute', 'ATLN, SNDG')
# ('Community Network Center Inc.', 'CHCG, DLLS, HSTN, NY54, SNDG, STTL')
# ('Comnet Bulgaria Holding Ltd.', 'ATLN, LA03, PHLA, SNAN, SNFN')
# ('Company "Zagalni Merezhi" Ltd', 'NY54, STLS')
# ('Company Relant Ltd', 'ATLN, DNVR, LA03, PTLD')
# ('Company for communications services ONE.VIP DOO Skopje', 'DLLS, NY54')
# ('Company with additional responsibility "Company "BEST"', 'ATLN, DNVR, SCRM, SLKC')
# ('Compañía Dominicana de Teléfonos, C. por A. - CODETEL', 'LA03, RLGH')
# ('Computer Center', 'CHCG, DLLS, DNVR, NY54, PHLA, SNDG, SNFN')
# ('Computer Engineering & Consulting, Ltd.', 'CMBR, DLLS, DNVR, NY54, STLS')
# ('Computer Methods International Corp.', 'NSVL, SNAN, STLS')
# ('Computer Sciences Corporation', 'CLEV, NSVL, SCRM, SNFN')
# ('Comsat Inc.', 'ATLN, CMBR, NWOR')
# ('Comsat Max ISP', 'CHCG, HSTN, SNAN')
# ('Comsenz', 'DNVR, SNFN')
# ('Comsys (GH) Limited', 'ATLN, DLLS, KSCY, LA03, PHLA, RLGH, SNAN')
# ('Comteco Ltda', 'CMBR, HSTN, LA03, RLGH, STLS, STTL')
# ('Comunicaciones Enersol, S.L.', 'CMBR, PHNX, RLGH, STTL')
# ('Comunidad Autonoma de la Region de Murcia', 'CMBR, HSTN, NSVL, PHNX, PTLD, RLGH, SCRM, SNAN')
# ('Comwave Telecom Inc.', 'DLLS, KSCY, SNAN, STLS')
# ('ConXioN Corporation', 'ATLN, HSTN')
# ('Concisa, Comunicacion, Marketing y Servicios S.L.', 'CHCG, DNVR, PHLA, PHNX, RLGH')
# ('Conecta Minas Telecom LTDA', 'DNVR, HSTN, LA03, PHLA, STLS, STTL')
# ('Conexão Serviços de Hospedagem na Web Ltda - EPP', 'ATLN, CHCG, DLLS, KSCY, PHNX, SCRM')
# ('Confluence Networks Inc', 'DNVR, PHLA, PHNX')
# ('Cong ty CP Truyen thong quoc te Incom', 'CHCG, CLEV, HSTN, LA03')
# ('Congressional Budget Office', 'CLEV, PTLD, SLKC')
# ('Connecticut State University System', 'ATLN, HSTN, KSCY, PHLA, PHNX, SNFN')
# ('Consejo General de la Abogacia Espanola', 'NWOR, NY54, SNAN, SNFN')
# ('Consolidated Data Services', 'CLEV, DNVR, PHNX, STTL')
# ('Consolidated Smart Systems LLC', 'ORLD, RLGH')
# ('Constant Contact, Inc', 'ORLD, PTLD, SNDG')
# ('Consult Informatica Ltda', 'CHCG, NWOR, NY54')
# ('Consultronic S.A.E.C.A.', 'ATLN, DNVR, SNFN')
# ('Consumerinfo.com, Inc.', 'PHLA, RLGH, SNAN, STLS')
# ('Contact 24, LTD', 'LA03, RLGH')
# ('Contina', 'CHCG, LA03, ORLD, PHLA')
# ('Continental Casualty Co. (CNA)', 'DLLS, RLGH, SLKC, SNDG')
# ('Converge ICT Solutions Inc.', 'CHCG, DNVR, PHNX')
# ('Convergia Argentina S.A.', 'NSVL, SCRM')
# ('Convoke Communications Corp.', 'DNVR, PHLA, SNDG, SNFN')
# ('Cool Messages Ltd.', 'CHCG, CLEV, ORLD, PHLA, PHNX, SLKC, SNFN')
# ('Coolnet New Communication Provider', 'NY54, PHNX, SNAN, SNFN')
# ('Coop. Eléctrica y de Servicios Públicos Luján', 'CHCG, DNVR, HSTN, LA03, NY54, ORLD, SNFN')
# ('Coop. Ltda de Electricidad y Servicios Anexos de Huinca Renancó', 'STLS, STTL')
# ('Coop. Popular de Elec., Obras y Servicios Pub. de Santa Rosa LTDA', 'DLLS, KSCY, NY54, PTLD')
# ('Coop. Telefónica y de obras y serv. públicos de Villa Flandria', 'LA03, NSVL, NY54, RLGH')
# ('Cooperativa Electrica de Galvez Ltda.', 'CHCG, DNVR, HSTN, NY54, RLGH, STLS')
# ('Cooperativa Eléctrica Antonio Carboni Ltda', 'ATLN, KSCY, NWOR, PHNX, SLKC, STTL')
# ('Cooperativa Telefonica Benavidez Ltda', 'DLLS, PHNX, SNFN')
# ('Cooperativa Telefonica Del Viso', 'ORLD, PTLD')
# ('Cooperativa Villa del Rosario (Coovilros)', 'PHLA, PHNX, STLS')
# ('CoreLink Data Centers', 'KSCY, LA03')
# ('Coreix Ltd', 'KSCY, NSVL, ORLD, PHLA, RLGH, SNAN, SNFN')
# ('Corporacio Megatel S.L.', 'ATLN, LA03, STTL')
# ('Corporación Telemic C.A.', 'DLLS, DNVR, SNDG, SNFN, STLS')
# ('Corporate Colocation Inc.', 'PHNX, SCRM, STLS')
# ('Corrections Corporation of America', 'HSTN, PTLD, SCRM, SLKC')
# ('Cosium sarl', 'ATLN, DNVR')
# ('Cosmote Mobile Telecommunications S.A.', 'ATLN, CHCG, CLEV, NY54, STLS, STTL')
# ('County of Orange', 'ATLN, HSTN, NY54, ORLD, PHLA, STTL')
# ('Covenant Healthcare Systems, Inc.', 'DNVR, RLGH, SLKC')
# ('Cox Communications Inc.', 'CHCG, DLLS, SNFN')
# ('Critical Case s.r.l', 'CHCG, CLEV, NWOR, STLS')
# ('Crnogorski Telekom a.d.Podgorica', 'CHCG, NSVL')
# ('Cross Country TV Ltd', 'CHCG, CLEV, HSTN, LA03, NSVL')
# ('Cumberland Technologies International', 'DNVR, NY54, SLKC')
# ('Custom Computer Specialists, Inc.', 'DLLS, DNVR, RLGH')
# ('Cvent, Inc.', 'ORLD, SNAN, SNDG')
# ('Cyber Access Internet Communications, Inc.', 'NWOR, PHNX')
# ('Cyber Channel International Ltd', 'ATLN, DNVR, NY54, ORLD, PTLD, STLS')
# ('Cyber Midia Emp., Assessoria e Informática', 'CHCG, DNVR, HSTN, STLS')
# ('CyberTech Ltd', 'CHCG, DNVR')
# ('Cybera Inc', 'CHCG, DLLS, NSVL, PHLA, PHNX, STTL')
# ('Cyberlink AG', 'ATLN, CHCG, CLEV, DLLS, STTL')
# ('Cyberverse, Inc.', 'LA03, NWOR, NY54, PHLA, SLKC, STTL')
# ('Cyfuture India Pvt. Ltd.', 'ATLN, DNVR, SCRM, SNFN')
# ('Cygate AB', 'CLEV, HSTN, NSVL, SNAN')
# ('Cynny Italia Srl', 'CLEV, CMBR, HSTN, PHLA, STTL')
# ('CyrusOne LLC', 'ORLD, PHNX, STLS')
# ('D+H Limited Partnership', 'CMBR, HSTN, NWOR, STLS')
# ('D-Vois Broadband Pvt Ltd', 'CHCG, DNVR, HSTN, NSVL, NWOR, PTLD, RLGH, SNDG')
# ('D. E. Shaw & Co.', 'NWOR, PTLD, RLGH, SCRM')
# ('D21 SA', 'CLEV, CMBR, DNVR, ORLD, PHNX, RLGH')
# ('DANA INNOVATION', 'CLEV, PHLA')
# ('DASSAULT SYSTEMES SE', 'CLEV, DLLS, HSTN, SLKC, SNDG')
# ('DATACOM CARIBE, INC.', 'CHCG, DLLS, SNFN, STLS, STTL')
# ('DATAK Internet Engineering, Inc', 'ATLN, CHCG, DLLS, PHNX, STTL')
# ('DB Network di Sgambaro Gionata', 'CHCG, KSCY, LA03, ORLD, PHLA, SNFN, STTL')
# ('DENDENA E CIA LTDA ME', 'ATLN, CHCG, CMBR, LA03, NWOR, SNFN')
# ('DENIC eG', 'ATLN, CHCG, CLEV, NWOR, SNDG, SNFN')
# ('DENIRO MARKETING, LLC.', 'CMBR, KSCY, NSVL, PHNX, RLGH, SCRM, STTL')
# ('DESEMPENHO PROVEDOR DE INTERNET', 'DNVR, RLGH')
# ('DETEL WIRELESS, LLC', 'ATLN, CHCG, DLLS, NY54, SLKC, SNDG, STLS')
# ('DHL Information Services (Europe) s.r.o', 'ORLD, PTLD, RLGH, SCRM, SNAN')
# ('DIANET Ltd.', 'SCRM, STLS')
# ('DIGINET TECNOLOGIA', 'DLLS, NY54, PTLD')
# ('DIGITAL WORK', 'DLLS, NSVL, PHLA, PHNX')
# ('DIGITALBANK, Inc., Regional ISP in Japan', 'CHCG, DLLS, HSTN, PHLA, STTL')
# ('DIRECT INTERNET LTD.', 'CHCG, HSTN, PHNX, RLGH, SNFN, STLS')
# ('DISENADORES INFORMATICOS Y TECNOLOGICOS, S.L.', 'ATLN, CMBR, PHLA')
# ('DLIVE', 'DLLS, LA03, PHNX, RLGH')
# ('DOGAN TV DIGITAL PLATFORM ISLETMECILIGI A.S', 'CLEV, DLLS, NWOR, SLKC, STTL')
# ('DOKOM Gesellschaft fuer Telekommunikation mbH', 'PHLA, STTL')
# ('DONG-EUI UNIVERSITY', 'DLLS, HSTN, NY54, PHNX, STTL')
# ('DSL Extreme', 'CLEV, DLLS, DNVR, NWOR, NY54, PTLD, SLKC')
# ('DSM Technology Consultants', 'KSCY, RLGH, STLS')
# ('DST Systems, Inc.', 'CLEV, CMBR, HSTN, NY54, RLGH, SNFN')
# ('DT Micro, inc.', 'RLGH, SLKC, SNAN, SNFN, STLS')
# ('DTC Informatica e Telecomunicações LTDA', 'CLEV, LA03, NWOR, NY54, PTLD, RLGH, SNAN')
# ('DTSNETWORK', 'PTLD, STTL')
# ('DUZONBIZON', 'CHCG, HSTN, KSCY')
# ('DV Info Informatikai kft.', 'NSVL, NWOR, NY54, SLKC')
# ('DWMS New Business Agentur fuer Werbung und Verkauf GmbH', 'NY54, STLS')
# ('DXTL Tseung Kwan O Service', 'ATLN, CMBR, DLLS, HSTN, PHNX, SNFN, STTL')
# ('Dadeh Gostar Asr Novin P.J.S. Co.', 'NSVL, ORLD, PHNX, PTLD, RLGH, SLKC')
# ('Daegu Metropolitan Office of Education', 'CMBR, KSCY, NSVL, SNDG, SNFN')
# ('Daejon Metropolitan Office of Education', 'KSCY, NWOR, ORLD, PTLD, SLKC')
# ('Daewoo Information Systems', 'PHNX, SLKC')
# ('Daimler AG', 'CHCG, DLLS, HSTN, SNFN')
# ('Daisy Communications Ltd', 'NSVL, ORLD, RLGH')
# ('Dalhousie University', 'CLEV, ORLD')
# ('Dallas County Community College District', 'DLLS, DNVR, NSVL, NWOR, PTLD')
# ('Dallas Infrastructure Services, LLC', 'CMBR, DLLS, HSTN, PHNX, RLGH, SNFN')
# ('Dancer LLC', 'CMBR, DLLS, ORLD, STLS, STTL')
# ('Dancris Telecom L.L.C', 'DNVR, PHNX, SCRM, STTL')
# ('Dantes Media SRL', 'KSCY, STTL')
# ('Dar Al-Mustawred Trading Group Limited', 'NY54, SCRM')
# ('Dat, s.r.o.', 'ATLN, STTL')
# ('Data Communication Business Group', 'ATLN, CLEV, DLLS, KSCY, NWOR, SNDG')
# ('Data Moving Company', 'CLEV, ORLD, SLKC, SNFN')
# ('Data Transmission Network Corporation', 'CLEV, HSTN, KSCY, NY54, RLGH, SLKC, SNAN')
# ('DataBank Holdings, Ltd.', 'DLLS, NSVL')
# ('DataPipe, Inc.', 'DLLS, SCRM, SNAN, STTL')
# ('Dataknox Pty Limited', 'ATLN, CLEV, DLLS, NY54, SNDG, SNFN')
# ('Dataline Ltd', 'PHLA, PTLD, STLS')
# ('Datatelekom Telekomunikasyon Hiz. Dis Tic. Ltd. Sti.', 'DNVR, PHNX, PTLD')
# ('Datavag Informatica Ltda', 'ATLN, CHCG, HSTN, SNFN, STTL')
# ('Daystarr Communications', 'CLEV, DLLS, KSCY, NWOR, NY54, PHNX')
# ('Defense.Net, Inc', 'LA03, NSVL, ORLD, PHLA, PTLD, SNAN, STLS')
# ('Dehradun Enet Solutions Private Ltd', 'CMBR, DLLS, HSTN, NWOR, NY54, PHNX, RLGH, SNDG, SNFN, STLS')
# ('Dell Systems Corporation', 'DNVR, HSTN, NY54, ORLD, PHNX, SLKC, STLS')
# ('Dell, Inc.', 'CHCG, PHNX, RLGH, SNFN')
# ('Delta Telecom Ltd', 'ATLN, CHCG, HSTN, LA03')
# ('Delta Telecom Ltd.', 'ATLN, CLEV, CMBR, DLLS, LA03')
# ('Dembach Goo Informatik GmbH & Co. KG', 'ATLN, ORLD, RLGH')
# ('Den Digital Entertainment Pvt. Ltd. AS ISP india', 'ATLN, DNVR, PHLA, SLKC, SNDG, SNFN')
# ('Denkers-ICT B.V.', 'ORLD, SNFN')
# ('Dennis Rainer Warnholz trading as active-servers.com', 'CHCG, CLEV, KSCY, NWOR, PHLA, PHNX, RLGH')
# ('Departemen Energi dan Sumber Daya Mineral', 'CHCG, CLEV, KSCY, NY54, PHNX, SNFN')
# ('Departemen Luar Negeri Republik Indonesia', 'DLLS, NY54, PHNX, RLGH, SLKC, STLS, STTL')
# ('Department of Immigration and Border Protection', 'DNVR, NSVL, NY54')
# ('Department of Parliamentary Services,', 'CHCG, SCRM')
# ('Department of Posts', 'CHCG, CLEV, CMBR, HSTN, PTLD, RLGH')
# ('Descartes Systems (Belgium) NV', 'DNVR, ORLD')
# ('Desktop Network Solutions', 'CHCG, DLLS, HSTN, NSVL, PHLA, PHNX, STTL')
# ...
# ('Utah Education Network', 'NY54, SCRM, STTL')
# ('Utransit International Carrier Limited', 'ORLD, SCRM')
# ('V + NET INTERNET BANDA LARGA', 'LA03, STTL')
# ('VAINAVI INDUSTIES LTD, INTERNET SERVICE PROVIDER, INDIA', 'CLEV, DLLS')
# ('VAS Freitas Servicos de Internet Ltda', 'HSTN, NSVL')
# ('VASTRA GOTALANDS LANS LANDSTING', 'SCRM, SNFN')
# ('VELOSTAR', 'CHCG, DLLS, DNVR, HSTN, RLGH, SNAN, STTL')
# ('VESTITEL BG', 'LA03, NY54, SNFN, STLS')
# ('VIACOM INFORMÁTICA LTDA', 'CHCG, KSCY, NWOR, PHNX, STLS')
# ('VIASITE INTERNET LTDA', 'ORLD, PTLD')
# ('VIDOLU Group Pty Ltd-Web4Africa', 'CMBR, DLLS, NY54, SNAN, SNFN, STLS')
# ('VIPNET.IT s.r.l.', 'CMBR, HSTN, LA03, PTLD, SCRM')
# ('VIPTURBO COMÉRCIO & SERVIÇOS DE INFORMÁTICA LTDA', 'CHCG, NWOR, NY54, PTLD, RLGH, SCRM, STLS')
# ('VISOVISION S.L.', 'CLEV, NWOR, STLS')
# ('VIVA Bahrain BSC Closed', 'CHCG, SNAN, STLS')
# ('VKS-internet Ltd', 'ORLD, RLGH, STTL')
# ('VM OPENLINK COMUNICAÇÃO MULTIMIDIA E INFORMÁTICA L', 'CHCG, KSCY, NWOR, RLGH, SNDG, STLS')
# ('VMWARE', 'CLEV, KSCY, ORLD, PHNX, SCRM, SNAN, STTL')
# ('VMware International Ltd.', 'CHCG, CMBR, NSVL, SNDG')
# ('VNPT Corp', 'CHCG, HSTN, SLKC, SNFN')
# ('VODAFONE ESPANA S.A.U.', 'ATLN, CMBR, DLLS, NSVL, SLKC, SNAN, SNDG')
# ('VODAFONE GHANA AS INTERNATIONAL TRANSIT', 'CLEV, SNDG, STTL')
# ('VODAFONE ONO, S.A.', 'DNVR, LA03, NSVL, NY54, ORLD, SNAN')
# ('VODAFONE-PANAFON HELLENIC TELECOMMUNICATIONS COMPANY SA', 'ATLN, LA03, NSVL, NWOR, NY54, PHNX')
# ('VPNtranet, LLC.', 'DLLS, LA03')
# ('VSE NET GmbH', 'ATLN, HSTN, LA03, NSVL, NY54, PTLD')
# ('VSHosting s.r.o.', 'NSVL, PHLA, PHNX, SCRM')
# ('VSX Networks', 'CHCG, DNVR, PHLA, PHNX, RLGH, SLKC, STLS')
# ('VTEL HOLDINGS LIMITED/JORDAN CO.', 'CHCG, KSCY, PHLA, SNFN')
# ('Vac City KabelTV Ltd.', 'HSTN, LA03, NWOR')
# ('Valve Corporation', 'CHCG, SLKC')
# ('Vantage Technologies Systems Integration, LLC', 'CMBR, NWOR, PTLD, SLKC, STLS')
# ('Vaquero Network Services, LLC', 'DNVR, STLS')
# ('Vautron Rechenzentrum AG', 'DLLS, HSTN, SNAN, SNFN')
# ('Vega-Service, LLC', 'DLLS, HSTN, RLGH, SNFN')
# ('Velco Globalnetwork', 'CMBR, KSCY, NWOR, ORLD, PHLA, SLKC, STTL')
# ('Velcom', 'DNVR, KSCY, PTLD, SLKC')
# ('Velociter Wireless, Inc.', 'ATLN, CMBR, LA03, STTL')
# ('Ver Tv S.A.', 'CHCG, CMBR, HSTN, NSVL, NY54, PHNX, STLS')
# ('Verb Data Centre Pty Ltd', 'KSCY, ORLD, PTLD, SCRM, SNAN')
# ('Verein zur Foerderung eines Deutschen Forschungsnetzes e.V.', 'CHCG, KSCY, NWOR, PHLA, SLKC, SNDG')
# ('VeriSign Infrastructure & Operations', 'CHCG, NY54, PHNX')
# ('VeriTeknik Bilisim Ltd.', 'ATLN, HSTN, NSVL, NY54, PTLD, SNDG, SNFN')
# ('Verint-Systems-LTD', 'DNVR, HSTN, KSCY, LA03, NY54, PTLD, SNFN')
# ('Verivox GmbH', 'NWOR, PHLA, SNFN')
# ('Verizon Nederland B.V.', 'HSTN, PHNX')
# ('Verizon UK Limited', 'CMBR, KSCY, ORLD, SNDG')
# ('Versaweb, LLC', 'CHCG, DLLS, DNVR, NY54')
# ('Vertical Telecoms Pty Ltd', 'DLLS, NY54')
# ('ViDaNet Cabletelevision Provider Ltd.', 'SNAN, STLS')
# ('Via Link Telecomunicacoes', 'CHCG, CLEV, DNVR, PTLD, SLKC')
# ('ViaSat,Inc.', 'ATLN, CHCG, DLLS, NWOR, PHLA, RLGH, SNDG, STTL')
# ('ViaWest', 'PHNX, STLS')
# ('Vianet', 'CHCG, NWOR, PHLA, PTLD, RLGH, SNAN, SNFN')
# ('Videotron Telecom Ltee', 'CHCG, NWOR, STLS')
# ('Viet Solutions Services Trading Company Limited', 'PHLA, PHNX, SLKC, SNAN, SNFN')
# ('Vietnam HTS., JSC', 'ATLN, DNVR, NSVL')
# ('Vietnam Technology and Telecommunication JSC', 'CHCG, PHNX')
# ('Viettel Corporation', 'LA03, NSVL, NY54, ORLD')
# ('Viewqwest Pte Ltd', 'KSCY, ORLD')
# ('Vimpelcom Lao Co Ltd', 'DNVR, LA03, PHLA, PTLD, RLGH, SNDG, SNFN')
# ('Virgin Media Limited', 'HSTN, NY54, STLS')
# ('Virginia Polytechnic Institute and State Univ.', 'LA03, ORLD')
# ('VirtuaServer Informatica Ltda', 'CHCG, NWOR, NY54, SLKC, STLS')
# ('Virtual Access Internet BV', 'ATLN, DNVR, NY54, ORLD, SLKC, STTL')
# ('Virtual Datacentre Pty Ltd', 'NWOR, RLGH')
# ('Virtual Internet Ltda Me', 'CLEV, SCRM')
# ('Virtual Radiologic Corporation', 'DLLS, HSTN, KSCY, SLKC')
# ('Virtustream Inc.', 'ATLN, DNVR, HSTN, LA03, PHLA, SLKC, STTL')
# ('Visa Argentina S.A.', 'HSTN, PHNX, RLGH, STTL')
# ('Vision Net, Inc.', 'CLEV, DNVR, NY54, ORLD, PHNX')
# ('Visionary Communications, Inc.', 'ATLN, SLKC')
# ('Visualhosting.net', 'LA03, ORLD, SNFN, STLS')
# ('VivosWeb Inc.', 'CHCG, LA03, PHNX, SLKC')
# ('Vocational Training Council Hong Kong', 'HSTN, KSCY, RLGH, SNFN')
# ('Vocus Connect International Backbone', 'DLLS, PHLA')
# ('Vodafone Albania Sh.A.', 'CHCG, DNVR')
# ('Vodafone Data', 'ATLN, CHCG, NSVL, NY54, SLKC, SNDG, STLS')
# ('Vodafone Data - Egypt', 'ATLN, NWOR, NY54, SNFN, STLS')
# ('Vodafone Fiji Limited', 'CLEV, CMBR, NWOR')
# ('Vodafone Group PLC', 'CHCG, DNVR, PHNX')
# ('Vodafone Hungary Ltd.', 'ORLD, SNFN')
# ('Vodafone Romania S.A.', 'CMBR, HSTN, PHNX, SCRM, SNFN, STTL')
# ('Vodafone Telekomunikasyon A.S.', 'CHCG, DLLS, HSTN, LA03, NWOR')
# ('Voice & Data Telecommunications Co. Ltd', 'CLEV, LA03, ORLD, RLGH, SNFN, STTL')
# ('Volcano Internet provider', 'CMBR, DNVR, KSCY, NWOR, PHNX, RLGH')
# ('VolumeDrive', 'LA03, NY54')
# ('Volvo Information Technology AB', 'NY54, STTL')
# ('Vostok Ltd.', 'ATLN, DLLS, STTL')
# ('VostokMediaSvyaz Ltd.', 'ATLN, CMBR, PHNX, SLKC, STLS')
# ('Voxel Dot Net, Inc.', 'ATLN, DNVR, NSVL, NWOR, NY54, PHNX, PTLD')
# ('Voxility S.R.L.', 'ATLN, CHCG, DLLS, KSCY, NY54, SLKC, SNDG')
# ('W.W.GRAINGER', 'ATLN, CHCG, PHNX, PTLD, SNAN')
# ('WANNET Korlatolt Felelossegu Tarsasag', 'LA03, SLKC, SNAN')
# ('WAWB Pty Ltd', 'CHCG, CMBR, DLLS, HSTN, PHNX, SLKC, STTL')
# ('WCS', 'CLEV, LA03, PHNX')
# ('WEBE DIGITAL SDN. BHD.', 'ATLN, CMBR, DLLS, ORLD, PHLA, SCRM, SNAN, STLS')
# ('WEBHOST LIMITED', 'PHLA, PTLD, SCRM')
# ('WEBMAX TECNOLOGIA LTDA', 'ATLN, CLEV, KSCY, NWOR')
# ('WEBTEAM s.c. Igor Kwiecien, Adrian Pysz', 'ATLN, DLLS, DNVR, LA03, NY54, SNAN, STLS')
# ('WESTERN UNION COMPANY', 'HSTN, ORLD, PHLA, SNFN')
# ('WIFLY WAXCOM CONGO', 'ATLN, KSCY, PHLA, SNFN, STTL')
# ('WIIP TELECOM SERVIÇOS DE INTERNET LTDA', 'CHCG, KSCY, PHLA')
# ('WILLIAM ROBERTO ZAGO', 'DLLS, NWOR')
# ('WIND Telecom S.A.', 'DNVR, NY54')
# ('WINS, LLC', 'CLEV, ORLD')
# ('WISH NET PRIVATE LIMITED', 'CHCG, NSVL, RLGH, SLKC, SNFN')
# ('WM TELECOM BOCAIUVA LTDA. - ME', 'CLEV, DLLS, PHNX, PTLD, SCRM, SNFN')
# ('WN TELECOM LTDA - ME', 'PHLA, SNFN')
# ('WNET, S. A.', 'ATLN, NWOR, PHLA, PHNX, RLGH, SCRM, STLS')
# ('WOW Access', 'CLEV, CMBR, RLGH')
# ('WPP 2005 Limited', 'LA03, SNFN')
# ('WPX Energy, Inc.', 'ATLN, DLLS, KSCY, LA03, NWOR, PHLA')
# ('WVVA.net Inc.', 'LA03, NY54, ORLD, SNAN, SNFN, STLS')
# ('WZ Communications Inc.', 'KSCY, SNAN, STLS')
# ('Wachttoren-, Bijbel en Traktaatgenootschap Kerkgenootschap', 'LA03, NY54, PHNX, SNFN, STLS')
# ('Wal-Mart Stores Inc.', 'CMBR, NY54')
# ('Walkiria Pereira de Macedo ME', 'DNVR, NSVL, ORLD, PHNX, RLGH')
# ('Wamika Broadband Pvt Ltd', 'DLLS, PHLA')
# ('Wan & Lan Internet Pvt Ltd', 'CMBR, HSTN, NSVL, NY54')
# ('Wananchi Group (K) LTD', 'CHCG, ORLD, SNAN, STLS')
# ('Warian SAS', 'KSCY, PHNX, SNDG, SNFN')
# ('Watch Tower Bible and Tract Society of Canada', 'ATLN, CLEV, CMBR, LA03, ORLD, SLKC, SNFN')
# ('WatchMyNet International SRL', 'HSTN, NSVL, NWOR, PHLA')
# ('Wateen Telecom (Pvt.) Ltd.', 'CLEV, NSVL, ORLD, SLKC')
# ('Wave Broadband', 'CHCG, DNVR, NSVL, NY54, ORLD, SNAN, SNDG, STTL')
# ('Wavenet', 'KSCY, NSVL, PHLA, SNAN')
# ('Wayport, Inc.', 'NY54, STTL')
# ('Weatherly Cloud, Inc.', 'ORLD, SLKC')
# ('Web Werks (Dubai POP)', 'NWOR, PHLA, PHNX, SNAN')
# ('Web2mil S.A', 'DLLS, LA03, NY54, SLKC')
# ('Web4Soft Internet s.r.o.', 'PHLA, STTL')
# ('Webair Internet Development Company Inc.', 'CMBR, HSTN, PHLA, RLGH, SLKC, SNDG, SNFN')
# ('Webhosting.Net, Inc.', 'HSTN, PHLA, SLKC, STLS')
# ('Webzilla B.V.', 'CHCG, DNVR, HSTN, NY54, ORLD, PHNX, SNFN')
# ('Webzone Internet, Internet Service Provider,', 'ATLN, DLLS, NSVL, NY54')
# ('Wefe Technology Pvt Ltd', 'SNFN, STTL')
# ('Weidenhammer', 'CLEV, DLLS, ORLD, SCRM, SNDG, STTL')
# ('Wellington Management Company, LLP', 'CHCG, HSTN, RLGH, SNFN')
# ('Wellpartner, Inc', 'HSTN, KSCY, ORLD')
# ('Wellstar Health System', 'HSTN, KSCY, SCRM, STLS')
# ('West Corporation', 'CMBR, DNVR, PHLA')
# ('West Indian Ocean Cable Company', 'CMBR, HSTN, KSCY, PHLA, SNFN')
# ('Westco Internet', 'CHCG, DNVR, HSTN, RLGH')
# ('Western Dental', 'ATLN, CLEV, CMBR, LA03, NSVL, ORLD, PTLD, SLKC')
# ('Weyerhaeuser Company', 'CHCG, DLLS, SNAN, SNFN')
# ('Where Are You Now Ltd', 'CLEV, NY54, ORLD, RLGH, SLKC, SNAN, SNFN')
# ('Whitestone Power & Communications', 'NSVL, RLGH, SNFN')
# ('Whole Sale', 'DLLS, STLS')
# ('Wholesale Services Provider', 'DNVR, HSTN, KSCY, PHLA')
# ('WiBand Communications', 'ATLN, HSTN, ORLD, PHLA, PHNX, SNFN, STLS')
# ('Wicked Networks', 'CHCG, NSVL, NY54, SLKC, SNAN')
# ('WideOpenWest Finance LLC', 'NWOR, STTL')
# ('Wideway do Brasil Ltda', 'DLLS, DNVR, NY54, PHNX, STLS')
# ('Wightman Telecom', 'DLLS, SLKC, SNDG')
# ('Willamette Valley Internet, L.L.C.', 'DLLS, NWOR, NY54, ORLD, SCRM, SNAN, SNDG, STTL')
# ('Wind Telecomunicazioni SpA', 'ATLN, DLLS, DNVR, NY54, PHLA, PHNX, SNAN')
# ('Windstream Communications LLC', 'CLEV, NY54, ORLD, RLGH, SNDG, SNFN')
# ('Windx Networks', 'LA03, NSVL, NY54, ORLD, SNAN')
# ('Winnebago Cooperative Telecom Association', 'CHCG, HSTN, SNFN')
# ('Wintek Corporation', 'ATLN, CLEV, NWOR, PHLA, PHNX, SCRM')
# ('Wipro Technologies,', 'CHCG, CLEV, DLLS, NY54, SNAN, SNFN')
# ('Wireless Comm Services LTDA', 'ORLD, PTLD, RLGH, SLKC, STLS')
# ('Wireline Solution India Pvt Ltd.', 'CLEV, KSCY, NWOR, PHLA, RLGH, SNFN')
# ('Wirtualna Polska S.A.', 'DNVR, HSTN, LA03, PHLA, PHNX, PTLD, RLGH, SLKC')
# ('Wirulink Pty Ltd', 'LA03, NY54, SCRM, STTL')
# ('Wisconsin CyberLynk Network, Inc.', 'NWOR, PTLD, SLKC')
# ('Wiva Telecom S.L.', 'CMBR, NSVL, NY54, SLKC, SNDG, SNFN')
# ('Wolseley UK Limited', 'ORLD, SNAN')
# ('Wood Group Management Services Ltd', 'ATLN, CLEV, HSTN, LA03, SNFN')
# ('WoodyNet', 'CMBR, NWOR, RLGH, SNDG, SNFN')
# ('Workday, Inc.', 'CHCG, DLLS, LA03, PHLA, SLKC, STTL')
# ('World Star Communication', 'ATLN, SNAN, STLS')
# ('WorldStream B.V.', 'KSCY, LA03, NY54')
# ('Worldcall Telecom Limited', 'ATLN, NSVL, NWOR, SNDG, SNFN')
# ('Worldcom de Costa Rica, S.A.', 'CHCG, NY54, RLGH, STTL')
# ('Worldline SA', 'CHCG, CMBR, NY54, PTLD, SLKC, SNAN')
# ('Worthington Industries Inc.', 'CLEV, DNVR, HSTN, ORLD, PHLA')
# ('Wowrack.com', 'CLEV, DNVR, ORLD, PHLA, PHNX, SNAN, SNFN')
# ('Wyoming Supreme Court', 'DNVR, NY54, PHLA, SCRM')
# ('X2nSat, Inc', 'CHCG, CLEV, LA03, ORLD, PHLA, RLGH, SNFN, STLS')
# ('XELLA Hungary Ltd', 'DLLS, NY54, SLKC')
# ('XING AG', 'HSTN, RLGH')
# ('XM Satellite Radio', 'CLEV, HSTN, NY54, ORLD')
# ('XMission, L.C.', 'CHCG, NWOR, STTL')
# ('XO Communications', 'DLLS, DNVR, PHNX')
# ('XPRESSBET INC.', 'LA03, PHLA, SLKC')
# ('XT GLOBAL NETWORKS LTD.', 'ATLN, PHLA, SLKC')
# ('Xairnet', 'ATLN, CMBR')
# ('XandraNet SRL', 'CLEV, NSVL, PHNX, RLGH')
# ('Xchange Telecom Corp.', 'ATLN, PHLA, SNDG, SNFN')
# ('XenoSite B.V.', 'DNVR, NSVL, PHLA, SLKC, SNDG, SNFN')
# ('Xetra Networks Inc.', 'NSVL, SNFN, STTL')
# ('Xglobe Online LTD', 'PHLA, SNDG, STTL')
# ('Xiangtan', 'KSCY, NY54, ORLD, PHNX, SNFN')
# ('Xplornet Communications Inc.', 'CLEV, STLS')
# ('Xs4all Internet BV', 'DLLS, ORLD, PHLA, SNDG')
# ('Xtrakter Ltd', 'ATLN, DNVR, LA03, NWOR, NY54, PHLA, PTLD, SCRM, SNDG')
# ('Xtreme.com.au Transit AS #1', 'CHCG, DLLS, DNVR, PHNX')
# ('YAHOO! SGA', 'LA03, STLS')
# ('YAX ADMINISTRACAO E TECNOLOGIA LTDA - ME', 'DLLS, RLGH, SNDG')
# ('YHC Corporation', 'CMBR, KSCY')
# ('YHSRV', 'DLLS, LA03, SLKC, STLS')
# ('YIP Telecom', 'CHCG, KSCY, RLGH, SLKC')
# ('YK Communications, Inc.', 'CLEV, DLLS, LA03, NY54, ORLD, SNFN')
# ('YOU Broadband & Cable India Ltd.', 'CHCG, CMBR, PTLD')
# ('YPT Entertainment House Pvt Ltd', 'DLLS, HSTN, PHNX, SLKC')
# ('Yahoo', 'HSTN, ORLD, PHLA, PHNX, SCRM, STTL')
# ('Yahoo Japan Corporation', 'ATLN, ORLD, PHLA, SNFN')
# ('Yale-New Haven Health Services Corporation', 'CHCG, HSTN, ORLD, PHNX')
# ('YarTV Ltd.', 'RLGH, SLKC')
# ('Yatanarpon Teleport Company Limited', 'NSVL, SNFN')
# ('YoAfrica (Pvt) Ltd', 'SNDG, STTL')
# ('Yota De Nicaragua', 'NSVL, NWOR, SNDG')
# ('Yuan-Jhen Info., Co., Ltd', 'ATLN, CHCG, CLEV, CMBR, ORLD, STTL')
# ('Yudhawira Khatulistiwa, PT', 'HSTN, PHLA, SNDG')
# ('ZAO Domodedodvo International Airport', 'CHCG, DLLS, HSTN, LA03, NY54, SNFN, STTL')
# ('ZAO ElectronTelecom', 'KSCY, NWOR, RLGH, SLKC, STTL')
# ('ZAO Prestige-Internet', 'NSVL, NWOR, SCRM, SNFN')
# ('ZAO Ratecom', 'CMBR, DLLS, HSTN, SNDG, STLS')
# ('ZAO Rosnefteflot', 'DNVR, HSTN, LA03, ORLD, RLGH')
# ('ZONES AS', 'DLLS, NWOR, PHNX, SLKC, STTL')
# ('ZS NETWORK (HONGKONG) LIMITED', 'ATLN, NSVL, PTLD, SNDG')
# ('ZSCALER, INC.', 'CLEV, PHLA, RLGH')
# ('ZUM TELECOM LTDA- ME', 'LA03, PHNX, SLKC, SNFN')
# ('Zabka Polska Sp. z o.o.', 'ATLN, CHCG, DLLS, NY54, PHLA, SCRM')
# ('Zapelini & Cia. Ltda.', 'CLEV, KSCY, ORLD, RLGH, STTL')
# ('Zavod RTA Ltd.', 'CHCG, DNVR, HSTN, NY54, SNDG, SNFN, STLS')
# ('Zayo Bandwidth', 'NY54, PHLA, SLKC, STLS, STTL')
# ('Zayo Bandwidth NorthEast LLC', 'CHCG, NWOR, ORLD')
# ('Zenlayer Inc', 'CLEV, LA03, RLGH, SLKC')
# ('Zettaline LTD', 'CHCG, HSTN, NY54, SNAN, SNFN')
# ('Zhengzhou longling technology ltd.', 'HSTN, LA03, ORLD, SNFN, STTL')
# ('Ziggo B.V.', 'DLLS, NWOR')
# ('Zone Networks Pty Ltd, Managed Hosting Solutions', 'CHCG, DLLS, NWOR, RLGH, SLKC, SNAN, STTL')
# ('Zoner Host SRL', 'CLEV, DLLS, PHNX, SLKC')
# ('Zscaler Switzerland GmbH', 'CHCG, ORLD, RLGH')
# ('Zumiez Inc.', 'LA03, NY54, SCRM, SNFN, STLS')
# ('aamra networks limited,', 'CMBR, LA03, NSVL, PHLA, SCRM, SLKC, STLS')
# ('adMarketplace, Inc.', 'DLLS, NWOR, SNAN')
# ('bol.com BV', 'CHCG, HSTN, STLS, STTL')
# ('cloudsky superfast broadband and services Pvt Ltd', 'ATLN, DLLS, KSCY, NWOR, PHLA, PHNX')
# ('delDSL Internet Pvt. Ltd.', 'CLEV, DLLS, PHLA, PHNX, SNFN')
# ('donga.com', 'CMBR, DNVR, ORLD, PTLD, STLS')
# ('dotXS Holding B.V.', 'ATLN, CLEV, DLLS, NY54, PHNX, SNFN, STTL')
# ('e-Bangla Limited', 'CLEV, CMBR, KSCY, LA03, NY54, ORLD')
# ('eNom, Incorporated', 'ATLN, CHCG, NSVL, NY54, PHNX')
# ('eNovance', 'CHCG, CMBR, DLLS, PHLA, RLGH, SNFN')
# ('eSited Solutions', 'CHCG, DNVR, LA03, NY54, RLGH, SNAN, STTL')
# ('euNetworks Managed Services GmbH', 'CMBR, DLLS')
# ('flexnetworks', 'CHCG, PHNX, SLKC')
# ('fusion services', 'DLLS, KSCY, NWOR')
# ('hibu inc.', 'CHCG, HSTN, PHNX, SLKC')
# ('hosthatch.com', 'CMBR, DLLS, KSCY, ORLD, PHNX')
# ('hosttech GmbH', 'CHCG, HSTN, SLKC, SNDG')
# ('i-Skill Dynamics Sdn Bhd', 'CHCG, CLEV, NWOR, NY54, SCRM, SLKC')
# ('i4HK Internet Solutions Company', 'DLLS, PHLA, PHNX, SNFN')
# ('iAdvantage Limited', 'CHCG, LA03, NSVL, ORLD, PHNX, STTL')
# ('iBasis, Inc.', 'ATLN, CLEV, CMBR, DLLS, LA03, SNAN')
# ('iConnectSA (Pty) Ltd', 'ATLN, CMBR, DLLS, LA03')
# ('iHeartCommunications, Inc.', 'CHCG, SNDG, SNFN')
# ('iONLINE INTERNET SERVICE PROVIDER', 'DLLS, ORLD')
# ('iPay Systems Ltd.', 'ATLN, NWOR, PTLD, RLGH')
# ('immensys AG', 'ATLN, DLLS, LA03, SNFN')
# ('inContact Inc.', 'ATLN, DLLS, LA03, NSVL, PTLD')
# ('infinity brasil telecom ltda me', 'CLEV, RLGH, SNDG')
# ('intY Ltd', 'ATLN, CHCG, CLEV, LA03, NY54, PTLD, SNAN')
# ('iseek Communications Pty Ltd', 'CLEV, PHNX')
# ('khalij fars Ettela Resan Company J.S.', 'HSTN, NY54, RLGH, SNFN')
# ('konectiva ltda', 'CHCG, STTL')
# ('lcp nv', 'ATLN, CMBR, DLLS, LA03, ORLD, SLKC, STTL')
# ('m & r serviços e telecomunicações ltda-me', 'DLLS, LA03, PHLA')
# ('manageNET Pty Ltd hosting services', 'CHCG, NSVL, SNDG, SNFN')
# ('marbis GmbH', 'CLEV, CMBR, SCRM')
# ('net.de AG', 'CHCG, HSTN, NSVL, PHLA, SLKC, STTL')
# ('netcup GmbH', 'CHCG, LA03, NWOR, SNFN')
# ('netirons', 'CLEV, NY54, PHNX, SCRM, SLKC, STTL')
# ('noris network AG', 'ATLN, CLEV, DLLS, ORLD, PHLA, SLKC')
# ('purplestones', 'CHCG, CLEV, NY54, ORLD, SNFN')
# ('rrbone UG (haftungsbeschraenkt)', 'CLEV, DNVR, HSTN, ORLD, PHLA, SNDG')
# ('schat.net', 'SNAN, STLS')
# ('sectorsix limited', 'CMBR, NY54, SNDG, SNFN, STLS')
# ('shanghai science and technology network communication limited company', 'NWOR, NY54, SCRM, SNDG, STLS, STTL')
# ('sky dot communication Limited', 'LA03, NWOR, RLGH, SCRM, SNFN, STLS')
# ('super midia tv a cabo ltda', 'ATLN, ORLD, SNDG, STTL')
# ('tfm associates', 'ATLN, CHCG, DLLS, STLS')
# ('ultraconexão soluçoes eireli', 'CLEV, CMBR, NWOR')
# ('wasted.io Ltd.', 'CHCG, DLLS, LA03, NY54')
# ('west central wireless', 'CHCG, KSCY, NSVL, NY54, SLKC')
# ('wyoming.com', 'ATLN, CMBR, PHNX')
# ('x-tention Informationstechnologie GmbH', 'CHCG, DNVR')
# ('youngsan university', 'KSCY, NWOR, SLKC')
# (None, 'ATLN, CMBR, DNVR, NSVL, NWOR, NY54, SLKC, SNDG')
